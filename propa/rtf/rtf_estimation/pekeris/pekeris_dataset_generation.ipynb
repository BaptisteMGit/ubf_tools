# %% [markdown]
# # Description générale
#
# Dans ce notebook on construit pas à pas un jeu de données test dans un guide d'onde de Pekeris en utilisant Kraken.
#
#
# L'environnement considéré est un guide d'onde de Pekeris dont les paramètres sont les suivants :
#
# * Dans la colonne d'eau :
#     * $c_0 = 1500 m/s$
#     * $\rho_0 = 1000 kg/m^3$
# * Dans le sédiment :
#     * $c_1$
#     * $\rho_1$
#     * $\alpha_1$
