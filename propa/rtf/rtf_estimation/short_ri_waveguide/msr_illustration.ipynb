# %%
import sys

sys.path.append(r"C:\Users\baptiste.menetrier\Desktop\devPy\phd")

# Load usefull functions
from propa.rtf.ideal_waveguide import *

# %% [markdown]
# # Objectifs
#
# Ce jupyter à pour objectif d'illustrer le processus automatique d'identification du lobe principal de la surface d'ambiguïté pour le rapport de CSI 2025. Pour plus de cohérence avec le reste du rapport, il s'agit ici d'illustrer le processus dans le cas de la localisation dans le plan (r,z) dans le guide d'onde de Pekeris (avec temps de RI faible).
