# %% [markdown]
# # Etude des performances de la méthode RTF MFP dans le cadre du cas test proposée par Zhang et al. 2023
# Publication de référence : Zhang, T., Zhou, D., Cheng, L., & Xu, W. (2023). Correlation-based passive localization: Linear system modeling and sparsity-aware optimization. The Journal of the Acoustical Society of America, 154(1), 295–306. https://doi.org/10.1121/10.0020154

# %%
# Importation des bibliothèques nécessaires
import sys
sys.path.append(r"C:\Users\baptiste.menetrier\Desktop\devPy\phd")

import numpy as np 

from propa.rtf.rtf_localisation.zhang_et_al_testcase.zhang_process_testcase import (
    process_all_snr,
    study_perf_vs_subarrays,
)
from propa.rtf.rtf_localisation.zhang_et_al_testcase.zhang_misc import get_subarrays

# %% [markdown]
# ## Test avec l'antenne complète à 6 capteurs
#
# ### Objectif
# L'objectif est simplement de reproduire les figures de perf d'ores et déjà obtenues avant correction de bugs importants.
#
# ### Paramètres
# Nombre de simulations = 10
# SNR = de -40 à +10 dB par pas de 5 dB
# Antenne = antenne hexagonale régulière de coté 250 m
# Sous-antennes étudiées : aucune
# Zone de recherche : zone réduite (mode debug)

# %%
nf = 100  # Nombre de points fréquentiel pour le calcul des grandeurs signantes (DCF, RTF)
dx, dy = 20, 20  # Taille des mailles de la grille de recherche
antenna_type = "zhang"  # Type d'antenne utilisée pour la simulation : antenne hexagonale (a = 250 m)
debug = True  # Calcul sur une zone réduite pour plus de rapidité (TODO changer pour la publication si la figure est ok)
event_stype = "wn"  # Signal source à localiser : bruit blanc gaussien

# Liste des sous antennes considérées : antenne complète à 6 capteurs
subarrays_list = list(get_subarrays(nr_fullarray=6, nr_subarray=6))
print(f"Number of subarrays = {len(subarrays_list)}")
print("Subarrays list : ", subarrays_list)

# Liste des SNR considérés
snrs = np.arange(-30, 15, 5)
print(f"Number of SNRs = {len(snrs)}")
print("SNR list : ", snrs)

# Nombre de simulations à réaliser pour chaque SNR
n_monte_carlo = 10
# Out:
# Number of subarrays = 1
# Subarrays list :  [array([0, 1, 2, 3, 4, 5])]
# Number of SNRs = 9
# SNR list :  [-30 -25 -20 -15 -10  -5   0   5  10]

# %%
# Paramètres graphiques pour la génération des figures
plot_args = {
    "plot_array": True,
    "plot_single_cpl_surf": False,
    "plot_fullarray_surf": False,
    "plot_cpl_surf_comparison": False,
    "plot_fullarray_surf_comparison": True,
    "plot_surf_dist_comparison": False,
    "plot_mainlobe_contour": False,
    "plot_msr_estimation": False,
}

# Calcul des MSR, RMSE pour chaque sous-antennes
process_all_snr(
    snrs,
    n_monte_carlo,
    dx=dx,
    dy=dy,
    nf=nf,
    freq_draw_method="equally_spaced",
    run_mode="a",
    subarrays_list=subarrays_list,
    antenna_type=antenna_type,
    debug=debug,
    verbose=True,
    check=True,
    plot_args=plot_args,
)
# Out:
# Start processing snr = -30 dB (i_mc from 0 to 9)
# i_mc = 0
# [########################################] | 100% Completed | 23.86 s
# GCC cpu time 32.92s
# [########################################] | 100% Completed | 21.53 s
# GCC cpu time 23.30s
# [########################################] | 100% Completed | 21.58 s
# GCC cpu time 24.85s
# [########################################] | 100% Completed | 22.55 s
# GCC cpu time 26.27s
# [########################################] | 100% Completed | 19.93 s
# GCC cpu time 23.63s
# [########################################] | 100% Completed | 20.03 s
# GCC cpu time 25.13s
# Features derived from time signal in 459.68 s
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -2.57 dB
# i_mc = 1
# [########################################] | 100% Completed | 20.22 s
# GCC cpu time 32.83s
# [########################################] | 100% Completed | 21.66 s
# GCC cpu time 25.20s
# [########################################] | 100% Completed | 21.47 s
# GCC cpu time 26.48s
# [########################################] | 100% Completed | 21.81 s
# GCC cpu time 23.95s
# [########################################] | 100% Completed | 21.69 s
# GCC cpu time 22.65s
# [########################################] | 100% Completed | 23.11 s
# GCC cpu time 26.75s
# Features derived from time signal in 440.66 s
# i_mc = 2
# [########################################] | 100% Completed | 21.36 s
# GCC cpu time 27.77s
# [########################################] | 100% Completed | 23.66 s
# GCC cpu time 27.52s
# [########################################] | 100% Completed | 23.11 s
# GCC cpu time 25.29s
# [########################################] | 100% Completed | 23.61 s
# GCC cpu time 25.92s
# [########################################] | 100% Completed | 24.19 s
# GCC cpu time 29.67s
# [########################################] | 100% Completed | 25.61 s
# GCC cpu time 31.74s
# Features derived from time signal in 475.89 s
# i_mc = 3
# [########################################] | 100% Completed | 21.02 s
# GCC cpu time 34.64s
# [########################################] | 100% Completed | 23.65 s
# GCC cpu time 27.15s
# [########################################] | 100% Completed | 23.28 s
# GCC cpu time 25.58s
# [########################################] | 100% Completed | 23.48 s
# GCC cpu time 27.16s
# [########################################] | 100% Completed | 22.28 s
# GCC cpu time 24.20s
# [########################################] | 100% Completed | 25.00 s
# GCC cpu time 24.45s
# Features derived from time signal in 465.04 s
# i_mc = 4
# [########################################] | 100% Completed | 20.68 s
# GCC cpu time 32.96s
# [########################################] | 100% Completed | 23.99 s
# GCC cpu time 26.38s
# [########################################] | 100% Completed | 22.84 s
# GCC cpu time 26.46s
# [########################################] | 100% Completed | 22.56 s
# GCC cpu time 25.59s
# [########################################] | 100% Completed | 23.94 s
# GCC cpu time 27.01s
# [########################################] | 100% Completed | 22.55 s
# GCC cpu time 24.37s
# Features derived from time signal in 454.03 s
# i_mc = 5
# [########################################] | 100% Completed | 19.87 s
# GCC cpu time 34.27s
# [########################################] | 100% Completed | 22.73 s
# GCC cpu time 25.72s
# [########################################] | 100% Completed | 21.39 s
# GCC cpu time 22.90s
# [########################################] | 100% Completed | 21.93 s
# GCC cpu time 23.89s
# [########################################] | 100% Completed | 22.26 s
# GCC cpu time 23.14s
# [########################################] | 100% Completed | 22.97 s
# GCC cpu time 25.56s
# Features derived from time signal in 449.52 s
# i_mc = 6
# [########################################] | 100% Completed | 19.84 s
# GCC cpu time 34.98s
# [########################################] | 100% Completed | 21.84 s
# GCC cpu time 24.35s
# [########################################] | 100% Completed | 21.63 s
# GCC cpu time 23.34s
# [########################################] | 100% Completed | 22.14 s
# GCC cpu time 25.96s
# [########################################] | 100% Completed | 23.35 s
# GCC cpu time 23.13s
# [########################################] | 100% Completed | 22.28 s
# GCC cpu time 23.65s
# Features derived from time signal in 439.47 s
# i_mc = 7
# [########################################] | 100% Completed | 19.44 s
# GCC cpu time 31.63s
# [########################################] | 100% Completed | 21.71 s
# GCC cpu time 24.22s
# [########################################] | 100% Completed | 21.19 s
# GCC cpu time 23.67s
# [########################################] | 100% Completed | 21.22 s
# GCC cpu time 22.77s
# [########################################] | 100% Completed | 21.95 s
# GCC cpu time 24.72s
# [########################################] | 100% Completed | 22.63 s
# GCC cpu time 26.16s
# Features derived from time signal in 431.35 s
# i_mc = 8
# [########################################] | 100% Completed | 19.60 s
# GCC cpu time 31.39s
# [########################################] | 100% Completed | 22.00 s
# GCC cpu time 23.25s
# [########################################] | 100% Completed | 22.25 s
# GCC cpu time 25.55s
# [########################################] | 100% Completed | 22.45 s
# GCC cpu time 21.77s
# [########################################] | 100% Completed | 21.91 s
# GCC cpu time 22.50s
# [########################################] | 100% Completed | 22.67 s
# GCC cpu time 21.73s
# Features derived from time signal in 435.87 s
# i_mc = 9
# [########################################] | 100% Completed | 18.39 s
# GCC cpu time 36.02s
# [########################################] | 100% Completed | 22.38 s
# GCC cpu time 25.58s
# [########################################] | 100% Completed | 21.83 s
# GCC cpu time 24.56s
# [########################################] | 100% Completed | 22.06 s
# GCC cpu time 23.27s
# [########################################] | 100% Completed | 22.92 s
# GCC cpu time 23.55s
# [########################################] | 100% Completed | 22.88 s
# GCC cpu time 22.08s
# Features derived from time signal in 436.91 s
# Start processing snr = -25 dB (i_mc from 0 to 9)
# i_mc = 0
# [########################################] | 100% Completed | 19.71 s
# GCC cpu time 40.82s
# [########################################] | 100% Completed | 21.22 s
# GCC cpu time 24.74s
# [########################################] | 100% Completed | 22.59 s
# GCC cpu time 25.42s
# [########################################] | 100% Completed | 22.28 s
# GCC cpu time 25.11s
# [########################################] | 100% Completed | 22.05 s
# GCC cpu time 24.27s
# [########################################] | 100% Completed | 23.26 s
# GCC cpu time 24.56s
# Features derived from time signal in 445.98 s
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -2.06 dB
# i_mc = 1
# [########################################] | 100% Completed | 19.43 s
# GCC cpu time 41.81s
# [########################################] | 100% Completed | 23.13 s
# GCC cpu time 24.51s
# [########################################] | 100% Completed | 21.52 s
# GCC cpu time 24.91s
# [########################################] | 100% Completed | 21.92 s
# GCC cpu time 23.18s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 21.51s
# [########################################] | 100% Completed | 21.67 s
# GCC cpu time 22.19s
# Features derived from time signal in 453.43 s
# i_mc = 2
# [########################################] | 100% Completed | 19.68 s
# GCC cpu time 38.50s
# [########################################] | 100% Completed | 20.64 s
# GCC cpu time 26.12s
# [########################################] | 100% Completed | 21.11 s
# GCC cpu time 24.41s
# [########################################] | 100% Completed | 21.34 s
# GCC cpu time 24.77s
# [########################################] | 100% Completed | 21.18 s
# GCC cpu time 23.82s
# [########################################] | 100% Completed | 21.42 s
# GCC cpu time 22.87s
# Features derived from time signal in 438.95 s
# i_mc = 3
# [########################################] | 100% Completed | 18.79 s
# GCC cpu time 37.53s
# [########################################] | 100% Completed | 21.56 s
# GCC cpu time 26.62s
# [########################################] | 100% Completed | 22.15 s
# GCC cpu time 23.83s
# [########################################] | 100% Completed | 22.23 s
# GCC cpu time 24.12s
# [########################################] | 100% Completed | 21.75 s
# GCC cpu time 23.00s
# [########################################] | 100% Completed | 22.77 s
# GCC cpu time 22.59s
# Features derived from time signal in 452.70 s
# i_mc = 4
# [########################################] | 100% Completed | 19.71 s
# GCC cpu time 38.86s
# [########################################] | 100% Completed | 21.58 s
# GCC cpu time 24.87s
# [########################################] | 100% Completed | 20.82 s
# GCC cpu time 23.59s
# [########################################] | 100% Completed | 22.66 s
# GCC cpu time 25.66s
# [########################################] | 100% Completed | 21.26 s
# GCC cpu time 23.39s
# [########################################] | 100% Completed | 21.92 s
# GCC cpu time 23.62s
# Features derived from time signal in 458.35 s
# i_mc = 5
# [########################################] | 100% Completed | 19.17 s
# GCC cpu time 38.45s
# [########################################] | 100% Completed | 21.58 s
# GCC cpu time 22.54s
# [########################################] | 100% Completed | 21.63 s
# GCC cpu time 25.33s
# [########################################] | 100% Completed | 21.23 s
# GCC cpu time 26.37s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 23.66s
# [########################################] | 100% Completed | 24.88 s
# GCC cpu time 26.47s
# Features derived from time signal in 465.78 s
# i_mc = 6
# [########################################] | 100% Completed | 20.25 s
# GCC cpu time 34.31s
# [########################################] | 100% Completed | 21.03 s
# GCC cpu time 23.84s
# [########################################] | 100% Completed | 21.79 s
# GCC cpu time 25.82s
# [########################################] | 100% Completed | 22.87 s
# GCC cpu time 25.33s
# [########################################] | 100% Completed | 21.90 s
# GCC cpu time 24.25s
# [########################################] | 100% Completed | 22.97 s
# GCC cpu time 23.21s
# Features derived from time signal in 446.09 s
# i_mc = 7
# [########################################] | 100% Completed | 19.80 s
# GCC cpu time 37.19s
# [########################################] | 100% Completed | 21.29 s
# GCC cpu time 24.93s
# [########################################] | 100% Completed | 22.35 s
# GCC cpu time 24.41s
# [########################################] | 100% Completed | 21.70 s
# GCC cpu time 23.88s
# [########################################] | 100% Completed | 21.89 s
# GCC cpu time 24.22s
# [########################################] | 100% Completed | 21.97 s
# GCC cpu time 23.72s
# Features derived from time signal in 442.14 s
# i_mc = 8
# [########################################] | 100% Completed | 20.32 s
# GCC cpu time 37.68s
# [########################################] | 100% Completed | 22.27 s
# GCC cpu time 24.64s
# [########################################] | 100% Completed | 21.05 s
# GCC cpu time 23.74s
# [########################################] | 100% Completed | 21.70 s
# GCC cpu time 24.45s
# [########################################] | 100% Completed | 22.49 s
# GCC cpu time 24.50s
# [########################################] | 100% Completed | 21.78 s
# GCC cpu time 25.29s
# Features derived from time signal in 450.09 s
# i_mc = 9
# [########################################] | 100% Completed | 19.08 s
# GCC cpu time 40.18s
# [########################################] | 100% Completed | 21.97 s
# GCC cpu time 25.60s
# [########################################] | 100% Completed | 21.92 s
# GCC cpu time 23.60s
# [########################################] | 100% Completed | 22.21 s
# GCC cpu time 24.66s
# [########################################] | 100% Completed | 21.95 s
# GCC cpu time 25.52s
# [########################################] | 100% Completed | 22.96 s
# GCC cpu time 30.32s
# Features derived from time signal in 453.44 s
# Start processing snr = -20 dB (i_mc from 0 to 9)
# i_mc = 0
# [########################################] | 100% Completed | 20.05 s
# GCC cpu time 40.98s
# [########################################] | 100% Completed | 21.00 s
# GCC cpu time 22.47s
# [########################################] | 100% Completed | 21.04 s
# GCC cpu time 27.06s
# [########################################] | 100% Completed | 22.29 s
# GCC cpu time 27.36s
# [########################################] | 100% Completed | 21.53 s
# GCC cpu time 24.14s
# [########################################] | 100% Completed | 21.81 s
# GCC cpu time 25.42s
# Features derived from time signal in 453.75 s
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -2.25 dB
# i_mc = 1
# [########################################] | 100% Completed | 19.92 s
# GCC cpu time 44.55s
# [########################################] | 100% Completed | 20.87 s
# GCC cpu time 23.34s
# [########################################] | 100% Completed | 23.37 s
# GCC cpu time 24.47s
# [########################################] | 100% Completed | 22.41 s
# GCC cpu time 25.46s
# [########################################] | 100% Completed | 22.24 s
# GCC cpu time 23.76s
# [########################################] | 100% Completed | 23.26 s
# GCC cpu time 23.10s
# Features derived from time signal in 448.01 s
# i_mc = 2
# [########################################] | 100% Completed | 19.74 s
# GCC cpu time 36.89s
# [########################################] | 100% Completed | 21.53 s
# GCC cpu time 24.65s
# [########################################] | 100% Completed | 22.47 s
# GCC cpu time 25.21s
# [########################################] | 100% Completed | 22.47 s
# GCC cpu time 23.70s
# [########################################] | 100% Completed | 21.91 s
# GCC cpu time 23.78s
# [########################################] | 100% Completed | 21.99 s
# GCC cpu time 23.93s
# Features derived from time signal in 449.96 s
# i_mc = 3
# [########################################] | 100% Completed | 19.37 s
# GCC cpu time 42.35s
# [########################################] | 100% Completed | 21.98 s
# GCC cpu time 25.00s
# [########################################] | 100% Completed | 20.70 s
# GCC cpu time 25.25s
# [########################################] | 100% Completed | 22.04 s
# GCC cpu time 24.18s
# [########################################] | 100% Completed | 22.13 s
# GCC cpu time 25.02s
# [########################################] | 100% Completed | 22.06 s
# GCC cpu time 25.64s
# Features derived from time signal in 461.88 s
# i_mc = 4
# [########################################] | 100% Completed | 20.08 s
# GCC cpu time 43.68s
# [########################################] | 100% Completed | 20.90 s
# GCC cpu time 22.41s
# [########################################] | 100% Completed | 22.42 s
# GCC cpu time 24.93s
# [########################################] | 100% Completed | 21.54 s
# GCC cpu time 23.01s
# [########################################] | 100% Completed | 21.82 s
# GCC cpu time 28.76s
# [########################################] | 100% Completed | 20.91 s
# GCC cpu time 22.26s
# Features derived from time signal in 480.19 s
# i_mc = 5
# [########################################] | 100% Completed | 19.03 s
# GCC cpu time 44.37s
# [########################################] | 100% Completed | 21.24 s
# GCC cpu time 23.65s
# [########################################] | 100% Completed | 21.51 s
# GCC cpu time 25.34s
# [########################################] | 100% Completed | 21.97 s
# GCC cpu time 24.42s
# [########################################] | 100% Completed | 21.98 s
# GCC cpu time 23.75s
# [########################################] | 100% Completed | 21.95 s
# GCC cpu time 23.78s
# Features derived from time signal in 452.31 s
# i_mc = 6
# [########################################] | 100% Completed | 20.11 s
# GCC cpu time 37.09s
# [########################################] | 100% Completed | 21.44 s
# GCC cpu time 23.42s
# [########################################] | 100% Completed | 21.63 s
# GCC cpu time 22.93s
# [########################################] | 100% Completed | 21.77 s
# GCC cpu time 24.27s
# [########################################] | 100% Completed | 22.41 s
# GCC cpu time 22.76s
# [########################################] | 100% Completed | 22.02 s
# GCC cpu time 24.21s
# Features derived from time signal in 440.55 s
# i_mc = 7
# [########################################] | 100% Completed | 21.38 s
# GCC cpu time 43.62s
# [########################################] | 100% Completed | 21.00 s
# GCC cpu time 25.55s
# [########################################] | 100% Completed | 21.94 s
# GCC cpu time 24.86s
# [########################################] | 100% Completed | 22.45 s
# GCC cpu time 23.38s
# [########################################] | 100% Completed | 22.71 s
# GCC cpu time 26.54s
# [########################################] | 100% Completed | 21.13 s
# GCC cpu time 25.93s
# Features derived from time signal in 476.65 s
# i_mc = 8
# [########################################] | 100% Completed | 19.84 s
# GCC cpu time 35.35s
# [########################################] | 100% Completed | 21.31 s
# GCC cpu time 25.13s
# [########################################] | 100% Completed | 22.09 s
# GCC cpu time 24.21s
# [########################################] | 100% Completed | 21.30 s
# GCC cpu time 24.35s
# [########################################] | 100% Completed | 21.42 s
# GCC cpu time 24.08s
# [########################################] | 100% Completed | 21.18 s
# GCC cpu time 23.67s
# Features derived from time signal in 461.58 s
# i_mc = 9
# [########################################] | 100% Completed | 20.00 s
# GCC cpu time 54.02s
# [########################################] | 100% Completed | 21.11 s
# GCC cpu time 23.91s
# [########################################] | 100% Completed | 22.17 s
# GCC cpu time 23.09s
# [########################################] | 100% Completed | 22.13 s
# GCC cpu time 25.71s
# [########################################] | 100% Completed | 22.18 s
# GCC cpu time 24.56s
# [########################################] | 100% Completed | 22.81 s
# GCC cpu time 23.01s
# Features derived from time signal in 466.65 s
# Start processing snr = -15 dB (i_mc from 10 to 19)
# i_mc = 10
# [########################################] | 100% Completed | 18.70 s
# GCC cpu time 48.30s
# [########################################] | 100% Completed | 21.20 s
# GCC cpu time 25.23s
# [########################################] | 100% Completed | 22.17 s
# GCC cpu time 23.78s
# [########################################] | 100% Completed | 22.43 s
# GCC cpu time 23.23s
# [########################################] | 100% Completed | 21.92 s
# GCC cpu time 23.91s
# [########################################] | 100% Completed | 22.75 s
# GCC cpu time 27.70s
# Features derived from time signal in 495.98 s
# MSR d_gcc : -0.28 dB
# MSR d_rtf : -2.73 dB
# i_mc = 11
# [########################################] | 100% Completed | 20.14 s
# GCC cpu time 61.80s
# [########################################] | 100% Completed | 20.91 s
# GCC cpu time 24.79s
# [########################################] | 100% Completed | 21.25 s
# GCC cpu time 25.67s
# [########################################] | 100% Completed | 21.37 s
# GCC cpu time 26.55s
# [########################################] | 100% Completed | 21.58 s
# GCC cpu time 26.05s
# [########################################] | 100% Completed | 20.88 s
# GCC cpu time 23.21s
# Features derived from time signal in 518.81 s
# i_mc = 12
# [########################################] | 100% Completed | 20.15 s
# GCC cpu time 51.42s
# [########################################] | 100% Completed | 20.65 s
# GCC cpu time 242.50s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 290.82s
# [########################################] | 100% Completed | 20.63 s
# GCC cpu time 567.84s
# [########################################] | 100% Completed | 18.37 s
# GCC cpu time 858.17s
# [########################################] | 100% Completed | 18.27 s
# GCC cpu time 452.24s
# Features derived from time signal in 3159.33 s
# i_mc = 13
# [########################################] | 100% Completed | 20.52 s
# GCC cpu time 60.23s
# [########################################] | 100% Completed | 21.08 s
# GCC cpu time 23.38s
# [########################################] | 100% Completed | 20.99 s
# GCC cpu time 24.82s
# [########################################] | 100% Completed | 21.41 s
# GCC cpu time 23.79s
# [########################################] | 100% Completed | 21.69 s
# GCC cpu time 29.47s
# [########################################] | 100% Completed | 21.25 s
# GCC cpu time 30.12s
# Features derived from time signal in 497.85 s
# i_mc = 14
# [########################################] | 100% Completed | 20.47 s
# GCC cpu time 50.88s
# [########################################] | 100% Completed | 20.86 s
# GCC cpu time 22.62s
# [########################################] | 100% Completed | 22.61 s
# GCC cpu time 22.89s
# [########################################] | 100% Completed | 22.08 s
# GCC cpu time 22.22s
# [########################################] | 100% Completed | 21.35 s
# GCC cpu time 24.33s
# [########################################] | 100% Completed | 21.63 s
# GCC cpu time 26.97s
# Features derived from time signal in 477.05 s
# i_mc = 15
# [########################################] | 100% Completed | 20.56 s
# GCC cpu time 63.73s
# [########################################] | 100% Completed | 21.01 s
# GCC cpu time 25.13s
# [########################################] | 100% Completed | 20.92 s
# GCC cpu time 24.99s
# [########################################] | 100% Completed | 21.44 s
# GCC cpu time 23.69s
# [########################################] | 100% Completed | 21.73 s
# GCC cpu time 23.71s
# [########################################] | 100% Completed | 22.11 s
# GCC cpu time 23.14s
# Features derived from time signal in 486.70 s
# i_mc = 16
# [########################################] | 100% Completed | 19.67 s
# GCC cpu time 59.06s
# [########################################] | 100% Completed | 21.08 s
# GCC cpu time 24.59s
# [########################################] | 100% Completed | 20.90 s
# GCC cpu time 26.63s
# [########################################] | 100% Completed | 21.07 s
# GCC cpu time 24.36s
# [########################################] | 100% Completed | 22.43 s
# GCC cpu time 23.03s
# [########################################] | 100% Completed | 22.57 s
# GCC cpu time 23.79s
# Features derived from time signal in 483.11 s
# i_mc = 17
# [########################################] | 100% Completed | 18.96 s
# GCC cpu time 56.48s
# [########################################] | 100% Completed | 21.30 s
# GCC cpu time 23.06s
# [########################################] | 100% Completed | 21.50 s
# GCC cpu time 23.87s
# [########################################] | 100% Completed | 23.50 s
# GCC cpu time 25.81s
# [########################################] | 100% Completed | 21.49 s
# GCC cpu time 25.28s
# [########################################] | 100% Completed | 21.89 s
# GCC cpu time 25.14s
# Features derived from time signal in 501.44 s
# i_mc = 18
# [########################################] | 100% Completed | 22.78 s
# GCC cpu time 62.86s
# [########################################] | 100% Completed | 21.03 s
# GCC cpu time 22.87s
# [########################################] | 100% Completed | 20.95 s
# GCC cpu time 21.47s
# [########################################] | 100% Completed | 20.90 s
# GCC cpu time 21.67s
# [########################################] | 100% Completed | 21.38 s
# GCC cpu time 21.86s
# [########################################] | 100% Completed | 21.56 s
# GCC cpu time 21.72s
# Features derived from time signal in 475.72 s
# i_mc = 19
# [########################################] | 100% Completed | 20.16 s
# GCC cpu time 65.14s
# [########################################] | 100% Completed | 20.22 s
# GCC cpu time 24.36s
# [########################################] | 100% Completed | 21.11 s
# GCC cpu time 23.48s
# [########################################] | 100% Completed | 21.91 s
# GCC cpu time 23.87s
# [########################################] | 100% Completed | 22.37 s
# GCC cpu time 22.33s
# [########################################] | 100% Completed | 20.85 s
# GCC cpu time 28.88s
# Features derived from time signal in 510.14 s
# Start processing snr = -10 dB (i_mc from 0 to 9)
# i_mc = 0
# [########################################] | 100% Completed | 19.78 s
# GCC cpu time 61.63s
# [########################################] | 100% Completed | 21.25 s
# GCC cpu time 24.68s
# [########################################] | 100% Completed | 21.23 s
# GCC cpu time 23.97s
# [########################################] | 100% Completed | 22.53 s
# GCC cpu time 23.37s
# [########################################] | 100% Completed | 21.79 s
# GCC cpu time 24.02s
# [########################################] | 100% Completed | 21.52 s
# GCC cpu time 21.47s
# Features derived from time signal in 517.62 s
# MSR d_gcc : -0.77 dB
# MSR d_rtf : -2.88 dB
# i_mc = 1
# [########################################] | 100% Completed | 18.44 s
# GCC cpu time 81.41s
# [########################################] | 100% Completed | 20.94 s
# GCC cpu time 22.56s
# [########################################] | 100% Completed | 21.41 s
# GCC cpu time 22.77s
# [########################################] | 100% Completed | 22.19 s
# GCC cpu time 23.72s
# [########################################] | 100% Completed | 21.45 s
# GCC cpu time 25.90s
# [########################################] | 100% Completed | 22.30 s
# GCC cpu time 24.09s
# Features derived from time signal in 502.01 s
# i_mc = 2
# [########################################] | 100% Completed | 20.33 s
# GCC cpu time 59.25s
# [########################################] | 100% Completed | 21.48 s
# GCC cpu time 25.99s
# [########################################] | 100% Completed | 21.40 s
# GCC cpu time 23.15s
# [########################################] | 100% Completed | 21.62 s
# GCC cpu time 23.29s
# [########################################] | 100% Completed | 21.65 s
# GCC cpu time 24.34s
# [########################################] | 100% Completed | 22.06 s
# GCC cpu time 23.77s
# Features derived from time signal in 515.35 s
# i_mc = 3
# [########################################] | 100% Completed | 20.28 s
# GCC cpu time 62.32s
# [########################################] | 100% Completed | 20.00 s
# GCC cpu time 23.16s
# [########################################] | 100% Completed | 21.55 s
# GCC cpu time 27.88s
# [########################################] | 100% Completed | 21.18 s
# GCC cpu time 23.72s
# [########################################] | 100% Completed | 21.63 s
# GCC cpu time 24.05s
# [########################################] | 100% Completed | 22.20 s
# GCC cpu time 24.50s
# Features derived from time signal in 495.52 s
# i_mc = 4
# [########################################] | 100% Completed | 20.35 s
# GCC cpu time 54.45s
# [########################################] | 100% Completed | 21.47 s
# GCC cpu time 22.92s
# [########################################] | 100% Completed | 21.18 s
# GCC cpu time 23.20s
# [########################################] | 100% Completed | 21.62 s
# GCC cpu time 23.92s
# [########################################] | 100% Completed | 22.20 s
# GCC cpu time 26.47s
# [########################################] | 100% Completed | 22.07 s
# GCC cpu time 25.42s
# Features derived from time signal in 493.70 s
# i_mc = 5
# [########################################] | 100% Completed | 20.17 s
# GCC cpu time 61.15s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 23.35s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 23.48s
# [########################################] | 100% Completed | 21.34 s
# GCC cpu time 21.35s
# [########################################] | 100% Completed | 21.71 s
# GCC cpu time 23.80s
# [########################################] | 100% Completed | 21.52 s
# GCC cpu time 22.27s
# Features derived from time signal in 466.25 s
# i_mc = 6
# [########################################] | 100% Completed | 20.25 s
# GCC cpu time 47.14s
# [########################################] | 100% Completed | 21.29 s
# GCC cpu time 22.48s
# [########################################] | 100% Completed | 22.60 s
# GCC cpu time 23.90s
# [########################################] | 100% Completed | 22.29 s
# GCC cpu time 23.44s
# [########################################] | 100% Completed | 21.93 s
# GCC cpu time 24.25s
# [########################################] | 100% Completed | 22.53 s
# GCC cpu time 24.71s
# Features derived from time signal in 466.75 s
# i_mc = 7
# [########################################] | 100% Completed | 18.20 s
# GCC cpu time 59.05s
# [########################################] | 100% Completed | 21.16 s
# GCC cpu time 23.75s
# [########################################] | 100% Completed | 20.68 s
# GCC cpu time 22.60s
# [########################################] | 100% Completed | 21.35 s
# GCC cpu time 24.01s
# [########################################] | 100% Completed | 21.11 s
# GCC cpu time 22.16s
# [########################################] | 100% Completed | 21.32 s
# GCC cpu time 21.82s
# Features derived from time signal in 460.07 s
# i_mc = 8
# [########################################] | 100% Completed | 20.00 s
# GCC cpu time 49.65s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 24.22s
# [########################################] | 100% Completed | 22.03 s
# GCC cpu time 23.56s
# [########################################] | 100% Completed | 21.52 s
# GCC cpu time 29.38s
# [########################################] | 100% Completed | 21.64 s
# GCC cpu time 25.90s
# [########################################] | 100% Completed | 21.36 s
# GCC cpu time 27.92s
# Features derived from time signal in 477.05 s
# i_mc = 9
# [########################################] | 100% Completed | 20.23 s
# GCC cpu time 50.81s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 23.37s
# [########################################] | 100% Completed | 21.53 s
# GCC cpu time 24.15s
# [########################################] | 100% Completed | 22.03 s
# GCC cpu time 22.95s
# [########################################] | 100% Completed | 21.67 s
# GCC cpu time 24.11s
# [########################################] | 100% Completed | 22.23 s
# GCC cpu time 23.57s
# Features derived from time signal in 466.45 s
# Start processing snr = -5 dB (i_mc from 20 to 29)
# i_mc = 20
# [########################################] | 100% Completed | 20.21 s
# GCC cpu time 48.93s
# [########################################] | 100% Completed | 20.95 s
# GCC cpu time 23.79s
# [########################################] | 100% Completed | 21.67 s
# GCC cpu time 24.14s
# [########################################] | 100% Completed | 22.89 s
# GCC cpu time 25.40s
# [########################################] | 100% Completed | 22.14 s
# GCC cpu time 23.90s
# [########################################] | 100% Completed | 22.12 s
# GCC cpu time 23.14s
# Features derived from time signal in 481.68 s
# MSR d_gcc : -2.89 dB
# MSR d_rtf : -3.26 dB
# i_mc = 21
# [########################################] | 100% Completed | 18.28 s
# GCC cpu time 70.79s
# [########################################] | 100% Completed | 20.24 s
# GCC cpu time 24.02s
# [########################################] | 100% Completed | 22.15 s
# GCC cpu time 23.73s
# [########################################] | 100% Completed | 21.93 s
# GCC cpu time 24.16s
# [########################################] | 100% Completed | 22.10 s
# GCC cpu time 23.71s
# [########################################] | 100% Completed | 21.72 s
# GCC cpu time 29.21s
# Features derived from time signal in 500.08 s
# i_mc = 22
# [########################################] | 100% Completed | 19.34 s
# GCC cpu time 51.33s
# [########################################] | 100% Completed | 21.12 s
# GCC cpu time 26.03s
# [########################################] | 100% Completed | 21.83 s
# GCC cpu time 23.65s
# [########################################] | 100% Completed | 21.13 s
# GCC cpu time 21.75s
# [########################################] | 100% Completed | 22.20 s
# GCC cpu time 22.09s
# [########################################] | 100% Completed | 21.68 s
# GCC cpu time 23.44s
# Features derived from time signal in 501.95 s
# i_mc = 23
# [########################################] | 100% Completed | 19.82 s
# GCC cpu time 70.65s
# [########################################] | 100% Completed | 21.61 s
# GCC cpu time 22.98s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 22.79s
# [########################################] | 100% Completed | 22.26 s
# GCC cpu time 24.80s
# [########################################] | 100% Completed | 21.84 s
# GCC cpu time 23.32s
# [########################################] | 100% Completed | 23.04 s
# GCC cpu time 25.93s
# Features derived from time signal in 487.46 s
# i_mc = 24
# [########################################] | 100% Completed | 20.13 s
# GCC cpu time 53.73s
# [########################################] | 100% Completed | 21.12 s
# GCC cpu time 22.92s
# [########################################] | 100% Completed | 21.31 s
# GCC cpu time 23.50s
# [########################################] | 100% Completed | 21.72 s
# GCC cpu time 27.32s
# [########################################] | 100% Completed | 21.86 s
# GCC cpu time 25.78s
# [########################################] | 100% Completed | 21.20 s
# GCC cpu time 26.39s
# Features derived from time signal in 501.62 s
# i_mc = 25
# [########################################] | 100% Completed | 20.03 s
# GCC cpu time 56.82s
# [########################################] | 100% Completed | 21.29 s
# GCC cpu time 22.84s
# [########################################] | 100% Completed | 22.34 s
# GCC cpu time 23.78s
# [########################################] | 100% Completed | 22.68 s
# GCC cpu time 25.21s
# [########################################] | 100% Completed | 22.59 s
# GCC cpu time 27.25s
# [########################################] | 100% Completed | 22.33 s
# GCC cpu time 26.93s
# Features derived from time signal in 481.55 s
# i_mc = 26
# [########################################] | 100% Completed | 20.10 s
# GCC cpu time 63.55s
# [########################################] | 100% Completed | 20.39 s
# GCC cpu time 24.16s
# [########################################] | 100% Completed | 21.78 s
# GCC cpu time 25.76s
# [########################################] | 100% Completed | 21.99 s
# GCC cpu time 24.50s
# [########################################] | 100% Completed | 22.08 s
# GCC cpu time 27.55s
# [########################################] | 100% Completed | 21.99 s
# GCC cpu time 23.31s
# Features derived from time signal in 487.46 s
# i_mc = 27
# [########################################] | 100% Completed | 19.55 s
# GCC cpu time 52.74s
# [########################################] | 100% Completed | 20.97 s
# GCC cpu time 22.71s
# [########################################] | 100% Completed | 22.46 s
# GCC cpu time 23.11s
# [########################################] | 100% Completed | 21.95 s
# GCC cpu time 22.87s
# [########################################] | 100% Completed | 21.98 s
# GCC cpu time 29.42s
# [########################################] | 100% Completed | 22.00 s
# GCC cpu time 30.94s
# Features derived from time signal in 478.43 s
# i_mc = 28
# [########################################] | 100% Completed | 19.32 s
# GCC cpu time 52.37s
# [########################################] | 100% Completed | 20.69 s
# GCC cpu time 27.85s
# [########################################] | 100% Completed | 21.89 s
# GCC cpu time 22.29s
# [########################################] | 100% Completed | 22.61 s
# GCC cpu time 22.27s
# [########################################] | 100% Completed | 21.67 s
# GCC cpu time 21.75s
# [########################################] | 100% Completed | 21.64 s
# GCC cpu time 21.95s
# Features derived from time signal in 478.67 s
# i_mc = 29
# [########################################] | 100% Completed | 19.26 s
# GCC cpu time 56.66s
# [########################################] | 100% Completed | 21.19 s
# GCC cpu time 24.43s
# [########################################] | 100% Completed | 21.54 s
# GCC cpu time 24.38s
# [########################################] | 100% Completed | 21.76 s
# GCC cpu time 28.15s
# [########################################] | 100% Completed | 21.44 s
# GCC cpu time 24.53s
# [########################################] | 100% Completed | 21.54 s
# GCC cpu time 25.11s
# Features derived from time signal in 525.35 s
# Start processing snr = 0 dB (i_mc from 2 to 11)
# i_mc = 2
# [########################################] | 100% Completed | 20.51 s
# GCC cpu time 69.20s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 23.17s
# [########################################] | 100% Completed | 21.75 s
# GCC cpu time 22.42s
# [########################################] | 100% Completed | 22.24 s
# GCC cpu time 22.82s
# [########################################] | 100% Completed | 22.26 s
# GCC cpu time 22.15s
# [########################################] | 100% Completed | 22.19 s
# GCC cpu time 22.01s
# Features derived from time signal in 540.98 s
# MSR d_gcc : -3.71 dB
# MSR d_rtf : -3.62 dB
# i_mc = 3
# [########################################] | 100% Completed | 19.91 s
# GCC cpu time 40.95s
# [########################################] | 100% Completed | 21.61 s
# GCC cpu time 28.56s
# [########################################] | 100% Completed | 22.57 s
# GCC cpu time 26.47s
# [########################################] | 100% Completed | 22.74 s
# GCC cpu time 23.70s
# [########################################] | 100% Completed | 23.23 s
# GCC cpu time 25.10s
# [########################################] | 100% Completed | 23.28 s
# GCC cpu time 24.86s
# Features derived from time signal in 471.97 s
# i_mc = 4
# [########################################] | 100% Completed | 20.92 s
# GCC cpu time 39.42s
# [########################################] | 100% Completed | 21.94 s
# GCC cpu time 24.27s
# [########################################] | 100% Completed | 22.56 s
# GCC cpu time 30.46s
# [########################################] | 100% Completed | 23.38 s
# GCC cpu time 22.09s
# [########################################] | 100% Completed | 23.05 s
# GCC cpu time 26.53s
# [########################################] | 100% Completed | 23.08 s
# GCC cpu time 25.26s
# Features derived from time signal in 459.52 s
# i_mc = 5
# [########################################] | 100% Completed | 20.38 s
# GCC cpu time 46.93s
# [########################################] | 100% Completed | 20.39 s
# GCC cpu time 24.83s
# [########################################] | 100% Completed | 23.52 s
# GCC cpu time 25.61s
# [########################################] | 100% Completed | 22.23 s
# GCC cpu time 23.77s
# [########################################] | 100% Completed | 23.14 s
# GCC cpu time 24.37s
# [########################################] | 100% Completed | 23.02 s
# GCC cpu time 25.03s
# Features derived from time signal in 458.96 s
# i_mc = 6
# [########################################] | 100% Completed | 20.66 s
# GCC cpu time 33.12s
# [########################################] | 100% Completed | 22.37 s
# GCC cpu time 26.05s
# [########################################] | 100% Completed | 22.92 s
# GCC cpu time 24.03s
# [########################################] | 100% Completed | 23.00 s
# GCC cpu time 22.83s
# [########################################] | 100% Completed | 23.24 s
# GCC cpu time 24.55s
# [########################################] | 100% Completed | 21.80 s
# GCC cpu time 22.79s
# Features derived from time signal in 461.51 s
# i_mc = 7
# [########################################] | 100% Completed | 20.79 s
# GCC cpu time 40.26s
# [########################################] | 100% Completed | 21.57 s
# GCC cpu time 24.28s
# [########################################] | 100% Completed | 23.21 s
# GCC cpu time 22.11s
# [########################################] | 100% Completed | 22.76 s
# GCC cpu time 21.65s
# [########################################] | 100% Completed | 22.23 s
# GCC cpu time 21.78s
# [########################################] | 100% Completed | 22.67 s
# GCC cpu time 22.03s
# Features derived from time signal in 458.67 s
# i_mc = 8
# [########################################] | 100% Completed | 19.88 s
# GCC cpu time 38.73s
# [########################################] | 100% Completed | 22.00 s
# GCC cpu time 25.96s
# [########################################] | 100% Completed | 23.37 s
# GCC cpu time 26.96s
# [########################################] | 100% Completed | 23.35 s
# GCC cpu time 25.95s
# [########################################] | 100% Completed | 23.15 s
# GCC cpu time 24.02s
# [########################################] | 100% Completed | 23.78 s
# GCC cpu time 23.88s
# Features derived from time signal in 455.63 s
# i_mc = 9
# [########################################] | 100% Completed | 20.73 s
# GCC cpu time 50.48s
# [########################################] | 100% Completed | 26.40 s
# GCC cpu time 41.83s
# [########################################] | 100% Completed | 24.44 s
# GCC cpu time 39.61s
# [########################################] | 100% Completed | 23.96 s
# GCC cpu time 43.10s
# [########################################] | 100% Completed | 24.72 s
# GCC cpu time 37.32s
# [########################################] | 100% Completed | 23.68 s
# GCC cpu time 37.12s
# Features derived from time signal in 638.09 s
# i_mc = 10
# [########################################] | 100% Completed | 20.46 s
# GCC cpu time 36.43s
# [########################################] | 100% Completed | 25.26 s
# GCC cpu time 40.46s
# [########################################] | 100% Completed | 24.05 s
# GCC cpu time 38.52s
# [########################################] | 100% Completed | 23.72 s
# GCC cpu time 41.82s
# [########################################] | 100% Completed | 24.48 s
# GCC cpu time 35.08s
# [########################################] | 100% Completed | 24.36 s
# GCC cpu time 38.15s
# Features derived from time signal in 590.08 s
# i_mc = 11
# [########################################] | 100% Completed | 24.40 s
# GCC cpu time 57.83s
# [########################################] | 100% Completed | 25.00 s
# GCC cpu time 39.70s
# [########################################] | 100% Completed | 24.11 s
# GCC cpu time 36.62s
# [########################################] | 100% Completed | 24.92 s
# GCC cpu time 44.29s
# [########################################] | 100% Completed | 28.36 s
# GCC cpu time 43.94s
# [########################################] | 100% Completed | 25.67 s
# GCC cpu time 42.71s
# Features derived from time signal in 1580.50 s
# Start processing snr = 5 dB (i_mc from 0 to 9)
# i_mc = 0
# [########################################] | 100% Completed | 34.37 s
# GCC cpu time 42.47s
# [########################################] | 100% Completed | 33.24 s
# GCC cpu time 39.47s
# [########################################] | 100% Completed | 29.93 s
# GCC cpu time 51.58s
# [########################################] | 100% Completed | 25.19 s
# GCC cpu time 42.44s
# [########################################] | 100% Completed | 24.94 s
# GCC cpu time 39.18s
# [########################################] | 100% Completed | 24.36 s
# GCC cpu time 48.50s
# Features derived from time signal in 732.63 s
# MSR d_gcc : -4.12 dB
# MSR d_rtf : -4.10 dB
# i_mc = 1
# [########################################] | 100% Completed | 29.15 s
# GCC cpu time 47.25s
# [########################################] | 100% Completed | 27.65 s
# GCC cpu time 41.93s
# [########################################] | 100% Completed | 27.08 s
# GCC cpu time 41.57s
# [########################################] | 100% Completed | 25.76 s
# GCC cpu time 40.75s
# [########################################] | 100% Completed | 26.05 s
# GCC cpu time 41.11s
# [########################################] | 100% Completed | 24.66 s
# GCC cpu time 41.03s
# Features derived from time signal in 691.52 s
# i_mc = 2
# [########################################] | 100% Completed | 25.12 s
# GCC cpu time 47.04s
# [########################################] | 100% Completed | 24.98 s
# GCC cpu time 43.65s
# [########################################] | 100% Completed | 25.27 s
# GCC cpu time 40.70s
# [########################################] | 100% Completed | 24.20 s
# GCC cpu time 39.78s
# [########################################] | 100% Completed | 24.35 s
# GCC cpu time 38.38s
# [########################################] | 100% Completed | 24.29 s
# GCC cpu time 35.45s
# Features derived from time signal in 638.70 s
# i_mc = 3
# [########################################] | 100% Completed | 24.12 s
# GCC cpu time 43.18s
# [########################################] | 100% Completed | 24.98 s
# GCC cpu time 40.02s
# [########################################] | 100% Completed | 26.18 s
# GCC cpu time 40.96s
# [########################################] | 100% Completed | 25.85 s
# GCC cpu time 41.73s
# [########################################] | 100% Completed | 24.56 s
# GCC cpu time 42.43s
# [########################################] | 100% Completed | 28.67 s
# GCC cpu time 40.43s
# Features derived from time signal in 652.03 s
# i_mc = 4
# [########################################] | 100% Completed | 24.68 s
# GCC cpu time 46.76s
# [########################################] | 100% Completed | 24.86 s
# GCC cpu time 40.10s
# [########################################] | 100% Completed | 25.42 s
# GCC cpu time 38.94s
# [########################################] | 100% Completed | 24.50 s
# GCC cpu time 38.74s
# [########################################] | 100% Completed | 24.28 s
# GCC cpu time 37.90s
# [########################################] | 100% Completed | 25.17 s
# GCC cpu time 42.82s
# Features derived from time signal in 643.61 s
# i_mc = 5
# [########################################] | 100% Completed | 25.75 s
# GCC cpu time 50.78s
# [########################################] | 100% Completed | 25.75 s
# GCC cpu time 39.03s
# [########################################] | 100% Completed | 25.16 s
# GCC cpu time 40.05s
# [########################################] | 100% Completed | 25.32 s
# GCC cpu time 39.90s
# [########################################] | 100% Completed | 26.06 s
# GCC cpu time 38.85s
# [########################################] | 100% Completed | 25.45 s
# GCC cpu time 39.98s
# Features derived from time signal in 651.63 s
# i_mc = 6
# [########################################] | 100% Completed | 25.52 s
# GCC cpu time 44.94s
# [########################################] | 100% Completed | 26.45 s
# GCC cpu time 42.79s
# [########################################] | 100% Completed | 26.50 s
# GCC cpu time 41.33s
# [########################################] | 100% Completed | 28.34 s
# GCC cpu time 40.42s
# [########################################] | 100% Completed | 25.03 s
# GCC cpu time 39.45s
# [########################################] | 100% Completed | 24.27 s
# GCC cpu time 39.82s
# Features derived from time signal in 661.46 s
# i_mc = 7
# [########################################] | 100% Completed | 25.22 s
# GCC cpu time 46.33s
# [########################################] | 100% Completed | 24.89 s
# GCC cpu time 38.66s
# [########################################] | 100% Completed | 24.53 s
# GCC cpu time 42.45s
# [########################################] | 100% Completed | 24.88 s
# GCC cpu time 39.76s
# [########################################] | 100% Completed | 24.27 s
# GCC cpu time 36.37s
# [########################################] | 100% Completed | 24.09 s
# GCC cpu time 37.62s
# Features derived from time signal in 659.79 s
# i_mc = 8
# [########################################] | 100% Completed | 24.66 s
# GCC cpu time 51.92s
# [########################################] | 100% Completed | 25.29 s
# GCC cpu time 40.35s
# [########################################] | 100% Completed | 24.66 s
# GCC cpu time 38.05s
# [########################################] | 100% Completed | 25.33 s
# GCC cpu time 37.61s
# [########################################] | 100% Completed | 24.50 s
# GCC cpu time 36.65s
# [########################################] | 100% Completed | 25.51 s
# GCC cpu time 39.20s
# Features derived from time signal in 638.30 s
# i_mc = 9
# [########################################] | 100% Completed | 30.38 s
# GCC cpu time 50.85s
# [########################################] | 100% Completed | 28.40 s
# GCC cpu time 40.28s
# [########################################] | 100% Completed | 25.46 s
# GCC cpu time 47.02s
# [########################################] | 100% Completed | 25.71 s
# GCC cpu time 40.18s
# [########################################] | 100% Completed | 25.62 s
# GCC cpu time 43.46s
# [########################################] | 100% Completed | 25.67 s
# GCC cpu time 39.68s
# Features derived from time signal in 679.94 s
# Start processing snr = 10 dB (i_mc from 0 to 9)
# i_mc = 0
# [########################################] | 100% Completed | 25.44 s
# GCC cpu time 41.81s
# [########################################] | 100% Completed | 26.14 s
# GCC cpu time 41.70s
# [########################################] | 100% Completed | 25.61 s
# GCC cpu time 40.84s
# [########################################] | 100% Completed | 25.28 s
# GCC cpu time 40.10s
# [########################################] | 100% Completed | 25.19 s
# GCC cpu time 43.57s
# [########################################] | 100% Completed | 25.26 s
# GCC cpu time 38.26s
# Features derived from time signal in 659.71 s
# MSR d_gcc : -4.43 dB
# MSR d_rtf : -4.28 dB
# i_mc = 1
# [########################################] | 100% Completed | 25.33 s
# GCC cpu time 50.96s
# [########################################] | 100% Completed | 26.21 s
# GCC cpu time 41.33s
# [########################################] | 100% Completed | 26.00 s
# GCC cpu time 44.03s
# [########################################] | 100% Completed | 28.84 s
# GCC cpu time 51.29s
# [########################################] | 100% Completed | 24.29 s
# GCC cpu time 40.13s
# [########################################] | 100% Completed | 24.99 s
# GCC cpu time 40.43s
# Features derived from time signal in 693.97 s
# i_mc = 2
# [########################################] | 100% Completed | 24.51 s
# GCC cpu time 43.12s
# [########################################] | 100% Completed | 25.97 s
# GCC cpu time 40.15s
# [########################################] | 100% Completed | 27.11 s
# GCC cpu time 39.17s
# [########################################] | 100% Completed | 24.39 s
# GCC cpu time 37.39s
# [########################################] | 100% Completed | 24.47 s
# GCC cpu time 37.58s
# [########################################] | 100% Completed | 24.65 s
# GCC cpu time 38.79s
# Features derived from time signal in 630.84 s
# i_mc = 3
# [########################################] | 100% Completed | 27.34 s
# GCC cpu time 49.97s
# [########################################] | 100% Completed | 27.31 s
# GCC cpu time 42.68s
# [########################################] | 100% Completed | 25.69 s
# GCC cpu time 46.55s
# [########################################] | 100% Completed | 25.82 s
# GCC cpu time 39.17s
# [########################################] | 100% Completed | 24.19 s
# GCC cpu time 38.09s
# [########################################] | 100% Completed | 25.70 s
# GCC cpu time 39.49s
# Features derived from time signal in 668.49 s
# i_mc = 4
# [########################################] | 100% Completed | 26.68 s
# GCC cpu time 56.19s
# [########################################] | 100% Completed | 26.43 s
# GCC cpu time 40.77s
# [########################################] | 100% Completed | 25.44 s
# GCC cpu time 43.30s
# [########################################] | 100% Completed | 25.64 s
# GCC cpu time 39.18s
# [########################################] | 100% Completed | 25.45 s
# GCC cpu time 39.54s
# [########################################] | 100% Completed | 26.25 s
# GCC cpu time 40.41s
# Features derived from time signal in 681.12 s
# i_mc = 5
# [########################################] | 100% Completed | 25.48 s
# GCC cpu time 55.08s
# [########################################] | 100% Completed | 25.95 s
# GCC cpu time 42.28s
# [########################################] | 100% Completed | 26.16 s
# GCC cpu time 39.26s
# [########################################] | 100% Completed | 25.28 s
# GCC cpu time 41.25s
# [########################################] | 100% Completed | 25.41 s
# GCC cpu time 37.27s
# [########################################] | 100% Completed | 25.53 s
# GCC cpu time 44.57s
# Features derived from time signal in 667.65 s
# i_mc = 6
# [########################################] | 100% Completed | 25.77 s
# GCC cpu time 46.03s
# [########################################] | 100% Completed | 26.38 s
# GCC cpu time 42.13s
# [########################################] | 100% Completed | 25.96 s
# GCC cpu time 40.68s
# [########################################] | 100% Completed | 24.25 s
# GCC cpu time 37.00s
# [########################################] | 100% Completed | 24.81 s
# GCC cpu time 36.88s
# [########################################] | 100% Completed | 29.11 s
# GCC cpu time 41.05s
# Features derived from time signal in 661.10 s
# i_mc = 7
# [########################################] | 100% Completed | 23.68 s
# GCC cpu time 53.62s
# [########################################] | 100% Completed | 25.12 s
# GCC cpu time 36.95s
# [########################################] | 100% Completed | 24.52 s
# GCC cpu time 38.87s
# [########################################] | 100% Completed | 30.53 s
# GCC cpu time 37.55s
# [########################################] | 100% Completed | 24.44 s
# GCC cpu time 37.98s
# [########################################] | 100% Completed | 24.43 s
# GCC cpu time 37.51s
# Features derived from time signal in 655.07 s
# i_mc = 8
# [########################################] | 100% Completed | 24.21 s
# GCC cpu time 50.90s
# [########################################] | 100% Completed | 24.67 s
# GCC cpu time 39.65s
# [########################################] | 100% Completed | 24.52 s
# GCC cpu time 39.92s
# [########################################] | 100% Completed | 24.29 s
# GCC cpu time 39.65s
# [########################################] | 100% Completed | 24.29 s
# GCC cpu time 37.42s
# [########################################] | 100% Completed | 24.61 s
# GCC cpu time 38.90s
# Features derived from time signal in 634.03 s
# i_mc = 9
# [########################################] | 100% Completed | 24.23 s
# GCC cpu time 42.97s
# [########################################] | 100% Completed | 25.21 s
# GCC cpu time 40.69s
# [########################################] | 100% Completed | 25.23 s
# GCC cpu time 40.99s
# [########################################] | 100% Completed | 24.40 s
# GCC cpu time 41.92s
# [########################################] | 100% Completed | 24.43 s
# GCC cpu time 40.68s
# [########################################] | 100% Completed | 24.14 s
# GCC cpu time 49.79s
# Features derived from time signal in 656.15 s

# %% [markdown]
# ## Test 1 : Simulations pour la publication JASA EL
#
# ### Objectif
# L'objectif de cette première simulation est d'étudier les performances de la méthode RTF vis à vis des performances de la méthode DCF à faible SNR. En particulier on cherche à mettre en lumière les avantages de la méthode RTF lorsque le nombre de récepteurs de l'antenne augmente. Pour cela on considère l'ensemble des sous antennes de l'antenne hexagonale et on cherche à représenter les métriques MSR et RMSE en fonction du nombre de capteur. On souhaite également représenter l'amplitude des variations de ces métriques pour un même nombre de capteur afin de voir si la configuration des capteurs à une influence importante sur les méthodes étudiées.
#
# ### Paramètres
# Nombre de simulations = 10
# SNR = -10 dB
# Antenne = antenne hexagonale régulière de coté 250 m
# Sous-antennes étudiées : toutes les sous-antennes de 2 à 6 capteurs
# Zone de recherche : zone réduite (mode debug)

# %%
nf = 100  # Nombre de points fréquentiel pour le calcul des grandeurs signantes (DCF, RTF)
dx, dy = 20, 20  # Taille des mailles de la grille de recherche
antenna_type = "zhang"  # Type d'antenne utilisée pour la simulation : antenne hexagonale (a = 250 m)
debug = True  # Calcul sur une zone réduite pour plus de rapidité (TODO changer pour la publication si la figure est ok)
event_stype = "wn"  # Signal source à localiser : bruit blanc gaussien

# Liste des sous antennes considérées : toutes les sous antennes possibles pour 2, 3, 4, 5 et 6 récepteurs
subarrays_list = []
n_rcv = [2, 3, 4, 5, 6]
for i in n_rcv:
    subarrays_list += list(get_subarrays(nr_fullarray=6, nr_subarray=i))
print(f"Number of subarrays = {len(subarrays_list)}")
print("Subarrays list : ", subarrays_list)

# Liste des SNR considérés
snrs = [-15]

# Nombre de simulations à réaliser pour chaque SNR
n_monte_carlo = 80
# Out:
# Number of subarrays = 57
# Subarrays list :  [array([0, 1]), array([0, 2]), array([0, 3]), array([0, 4]), array([0, 5]), array([1, 2]), array([1, 3]), array([1, 4]), array([1, 5]), array([2, 3]), array([2, 4]), array([2, 5]), array([3, 4]), array([3, 5]), array([4, 5]), array([0, 1, 2]), array([0, 1, 3]), array([0, 1, 4]), array([0, 1, 5]), array([0, 2, 3]), array([0, 2, 4]), array([0, 2, 5]), array([0, 3, 4]), array([0, 3, 5]), array([0, 4, 5]), array([1, 2, 3]), array([1, 2, 4]), array([1, 2, 5]), array([1, 3, 4]), array([1, 3, 5]), array([1, 4, 5]), array([2, 3, 4]), array([2, 3, 5]), array([2, 4, 5]), array([3, 4, 5]), array([0, 1, 2, 3]), array([0, 1, 2, 4]), array([0, 1, 2, 5]), array([0, 1, 3, 4]), array([0, 1, 3, 5]), array([0, 1, 4, 5]), array([0, 2, 3, 4]), array([0, 2, 3, 5]), array([0, 2, 4, 5]), array([0, 3, 4, 5]), array([1, 2, 3, 4]), array([1, 2, 3, 5]), array([1, 2, 4, 5]), array([1, 3, 4, 5]), array([2, 3, 4, 5]), array([0, 1, 2, 3, 4]), array([0, 1, 2, 3, 5]), array([0, 1, 2, 4, 5]), array([0, 1, 3, 4, 5]), array([0, 2, 3, 4, 5]), array([1, 2, 3, 4, 5]), array([0, 1, 2, 3, 4, 5])]

# %%
# Paramètres graphiques pour la génération des figures
plot_args = {
    "plot_array": True,
    "plot_single_cpl_surf": False,
    "plot_fullarray_surf": False,
    "plot_cpl_surf_comparison": False,
    "plot_fullarray_surf_comparison": True,
    "plot_surf_dist_comparison": False,
    "plot_mainlobe_contour": False,
    "plot_msr_estimation": False,
}

# Calcul des MSR, RMSE pour chaque sous-antennes
process_all_snr(
    snrs,
    n_monte_carlo,
    dx=dx,
    dy=dy,
    nf=nf,
    freq_draw_method="equally_spaced",
    run_mode="a",
    subarrays_list=subarrays_list,
    antenna_type=antenna_type,
    debug=debug,
    verbose=True,
    check=True,
    plot_args=plot_args,
)
# Out:
# Start processing snr = -15 dB (i_mc from 30 to 109)
# i_mc = 30
# [########################################] | 100% Completed | 19.11 s
# GCC cpu time 32.05s
# [########################################] | 100% Completed | 17.96 s
# GCC cpu time 24.73s
# [########################################] | 100% Completed | 20.58 s
# GCC cpu time 25.72s
# [########################################] | 100% Completed | 20.42 s
# GCC cpu time 24.02s
# [########################################] | 100% Completed | 20.63 s
# GCC cpu time 23.56s
# [########################################] | 100% Completed | 20.53 s
# GCC cpu time 23.64s
# Features derived from time signal in 431.52 s
# MSR d_gcc : -0.07 dB
# MSR d_rtf : -0.35 dB
# MSR d_gcc : -0.39 dB
# MSR d_rtf : -0.46 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -0.80 dB
# MSR d_gcc : -0.82 dB
# MSR d_rtf : -0.35 dB
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -0.42 dB
# MSR d_gcc : -0.20 dB
# MSR d_rtf : -0.18 dB
# MSR d_gcc : -1.13 dB
# MSR d_rtf : -0.01 dB
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -0.02 dB
# MSR d_gcc : -0.21 dB
# MSR d_rtf : -0.00 dB
# MSR d_gcc : -0.32 dB
# MSR d_rtf : -0.19 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -0.26 dB
# MSR d_gcc : -0.17 dB
# MSR d_rtf : -0.41 dB
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -0.19 dB
# MSR d_gcc : -0.65 dB
# MSR d_rtf : -0.00 dB
# MSR d_gcc : -0.37 dB
# MSR d_rtf : -0.00 dB
# MSR d_gcc : -0.01 dB
# MSR d_rtf : -1.14 dB
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -0.83 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -0.70 dB
# MSR d_gcc : -0.05 dB
# MSR d_rtf : -1.41 dB
# MSR d_gcc : -0.18 dB
# MSR d_rtf : -1.03 dB
# MSR d_gcc : -0.07 dB
# MSR d_rtf : -0.13 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -0.92 dB
# MSR d_gcc : -0.09 dB
# MSR d_rtf : -0.34 dB
# MSR d_gcc : -0.14 dB
# MSR d_rtf : -1.04 dB
# MSR d_gcc : -0.79 dB
# MSR d_rtf : -0.60 dB
# MSR d_gcc : -0.08 dB
# MSR d_rtf : -0.00 dB
# MSR d_gcc : -0.21 dB
# MSR d_rtf : -0.35 dB
# MSR d_gcc : -0.08 dB
# MSR d_rtf : -0.29 dB
# MSR d_gcc : -0.32 dB
# MSR d_rtf : -0.12 dB
# MSR d_gcc : -0.08 dB
# MSR d_rtf : -0.11 dB
# MSR d_gcc : -0.17 dB
# MSR d_rtf : -0.34 dB
# MSR d_gcc : -0.54 dB
# MSR d_rtf : -0.52 dB
# MSR d_gcc : -0.15 dB
# MSR d_rtf : -0.26 dB
# MSR d_gcc : -0.40 dB
# MSR d_rtf : -0.31 dB
# MSR d_gcc : -0.50 dB
# MSR d_rtf : -0.04 dB
# MSR d_gcc : -0.07 dB
# MSR d_rtf : -2.37 dB
# MSR d_gcc : -0.11 dB
# MSR d_rtf : -0.94 dB
# MSR d_gcc : -0.02 dB
# MSR d_rtf : -1.40 dB
# MSR d_gcc : -0.41 dB
# MSR d_rtf : -1.87 dB
# MSR d_gcc : -0.16 dB
# MSR d_rtf : -2.04 dB
# MSR d_gcc : -0.09 dB
# MSR d_rtf : -1.47 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -1.44 dB
# MSR d_gcc : -0.35 dB
# MSR d_rtf : -1.57 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -1.19 dB
# MSR d_gcc : -0.69 dB
# MSR d_rtf : -1.55 dB
# MSR d_gcc : -0.26 dB
# MSR d_rtf : -0.04 dB
# MSR d_gcc : -0.31 dB
# MSR d_rtf : -0.45 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -0.17 dB
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -0.18 dB
# MSR d_gcc : -0.26 dB
# MSR d_rtf : -0.01 dB
# MSR d_gcc : -0.00 dB
# MSR d_rtf : -1.85 dB
# MSR d_gcc : -0.19 dB
# MSR d_rtf : -2.34 dB
# MSR d_gcc : -0.09 dB
# MSR d_rtf : -1.63 dB
# MSR d_gcc : -0.10 dB
# MSR d_rtf : -2.48 dB
# MSR d_gcc : -0.03 dB
# MSR d_rtf : -1.98 dB
# MSR d_gcc : -0.01 dB
# MSR d_rtf : -0.23 dB
# MSR d_gcc : -0.04 dB
# MSR d_rtf : -2.50 dB
# i_mc = 31
# [########################################] | 100% Completed | 19.34 s
# GCC cpu time 32.61s
# [########################################] | 100% Completed | 19.53 s
# GCC cpu time 22.86s
# [########################################] | 100% Completed | 20.53 s
# GCC cpu time 22.67s
# [########################################] | 100% Completed | 20.64 s
# GCC cpu time 22.87s
# [########################################] | 100% Completed | 21.19 s
# GCC cpu time 24.13s
# [########################################] | 100% Completed | 20.60 s
# GCC cpu time 25.40s
# Features derived from time signal in 414.99 s
# i_mc = 32
# [########################################] | 100% Completed | 20.33 s
# GCC cpu time 38.93s
# [########################################] | 100% Completed | 21.38 s
# GCC cpu time 24.60s
# [########################################] | 100% Completed | 21.58 s
# GCC cpu time 23.67s
# [########################################] | 100% Completed | 22.77 s
# GCC cpu time 26.33s
# [########################################] | 100% Completed | 22.05 s
# GCC cpu time 26.02s
# [########################################] | 100% Completed | 21.62 s
# GCC cpu time 25.06s
# Features derived from time signal in 478.77 s
# i_mc = 33
# [########################################] | 100% Completed | 20.80 s
# GCC cpu time 39.63s
# [########################################] | 100% Completed | 27.10 s
# GCC cpu time 25.91s
# [########################################] | 100% Completed | 21.86 s
# GCC cpu time 25.25s
# [########################################] | 100% Completed | 22.35 s
# GCC cpu time 23.14s
# [########################################] | 100% Completed | 25.30 s
# GCC cpu time 33.18s
# [########################################] | 100% Completed | 22.85 s
# GCC cpu time 27.18s
# Features derived from time signal in 487.64 s
# i_mc = 34
# [########################################] | 100% Completed | 20.67 s
# GCC cpu time 42.79s
# [########################################] | 100% Completed | 20.96 s
# GCC cpu time 25.47s
# [########################################] | 100% Completed | 20.51 s
# GCC cpu time 25.37s
# [########################################] | 100% Completed | 20.48 s
# GCC cpu time 23.63s
# [########################################] | 100% Completed | 20.92 s
# GCC cpu time 22.73s
# [########################################] | 100% Completed | 21.16 s
# GCC cpu time 21.72s
# Features derived from time signal in 446.80 s
# i_mc = 35
# [########################################] | 100% Completed | 19.42 s
# GCC cpu time 38.40s
# [########################################] | 100% Completed | 21.58 s
# GCC cpu time 24.77s
# [########################################] | 100% Completed | 20.97 s
# GCC cpu time 23.72s
# [########################################] | 100% Completed | 21.34 s
# GCC cpu time 23.03s
# [########################################] | 100% Completed | 21.52 s
# GCC cpu time 22.78s
# [########################################] | 100% Completed | 21.59 s
# GCC cpu time 26.46s
# Features derived from time signal in 435.24 s
# i_mc = 36
# [########################################] | 100% Completed | 19.69 s
# GCC cpu time 35.85s
# [########################################] | 100% Completed | 20.59 s
# GCC cpu time 23.48s
# [########################################] | 100% Completed | 20.49 s
# GCC cpu time 23.63s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 24.15s
# [########################################] | 100% Completed | 20.48 s
# GCC cpu time 31.76s
# [########################################] | 100% Completed | 20.78 s
# GCC cpu time 24.03s
# Features derived from time signal in 452.02 s
# i_mc = 37
# [########################################] | 100% Completed | 19.62 s
# GCC cpu time 38.50s
# [########################################] | 100% Completed | 20.59 s
# GCC cpu time 22.99s
# [########################################] | 100% Completed | 22.56 s
# GCC cpu time 28.45s
# [########################################] | 100% Completed | 22.45 s
# GCC cpu time 23.55s
# [########################################] | 100% Completed | 21.40 s
# GCC cpu time 25.35s
# [########################################] | 100% Completed | 21.85 s
# GCC cpu time 22.82s
# Features derived from time signal in 445.38 s
# i_mc = 38
# [########################################] | 100% Completed | 19.74 s
# GCC cpu time 42.48s
# [########################################] | 100% Completed | 21.68 s
# GCC cpu time 23.76s
# [########################################] | 100% Completed | 21.68 s
# GCC cpu time 23.05s
# [########################################] | 100% Completed | 21.92 s
# GCC cpu time 23.93s
# [########################################] | 100% Completed | 22.51 s
# GCC cpu time 23.76s
# [########################################] | 100% Completed | 23.64 s
# GCC cpu time 25.00s
# Features derived from time signal in 461.18 s
# i_mc = 39
# [########################################] | 100% Completed | 20.64 s
# GCC cpu time 49.47s
# [########################################] | 100% Completed | 21.80 s
# GCC cpu time 25.02s
# [########################################] | 100% Completed | 24.56 s
# GCC cpu time 25.53s
# [########################################] | 100% Completed | 23.41 s
# GCC cpu time 28.18s
# [########################################] | 100% Completed | 23.34 s
# GCC cpu time 25.95s
# [########################################] | 100% Completed | 23.83 s
# GCC cpu time 23.02s
# Features derived from time signal in 466.80 s
# i_mc = 40
# [########################################] | 100% Completed | 21.06 s
# GCC cpu time 38.66s
# [########################################] | 100% Completed | 22.47 s
# GCC cpu time 25.75s
# [########################################] | 100% Completed | 22.97 s
# GCC cpu time 24.13s
# [########################################] | 100% Completed | 23.06 s
# GCC cpu time 25.13s
# [########################################] | 100% Completed | 22.73 s
# GCC cpu time 24.65s
# [########################################] | 100% Completed | 22.78 s
# GCC cpu time 24.39s
# Features derived from time signal in 464.22 s
# i_mc = 41
# [########################################] | 100% Completed | 23.77 s
# GCC cpu time 45.03s
# [########################################] | 100% Completed | 21.10 s
# GCC cpu time 24.06s
# [########################################] | 100% Completed | 21.20 s
# GCC cpu time 24.63s
# [########################################] | 100% Completed | 20.93 s
# GCC cpu time 25.79s
# [########################################] | 100% Completed | 21.30 s
# GCC cpu time 25.71s
# [########################################] | 100% Completed | 22.35 s
# GCC cpu time 30.10s
# Features derived from time signal in 471.45 s
# i_mc = 42
# [########################################] | 100% Completed | 19.46 s
# GCC cpu time 46.25s
# [########################################] | 100% Completed | 20.51 s
# GCC cpu time 24.04s
# [########################################] | 100% Completed | 21.13 s
# GCC cpu time 24.79s
# [########################################] | 100% Completed | 20.75 s
# GCC cpu time 26.37s
# [########################################] | 100% Completed | 21.13 s
# GCC cpu time 22.47s
# [########################################] | 100% Completed | 22.77 s
# GCC cpu time 26.08s
# Features derived from time signal in 468.57 s
# i_mc = 43
# [########################################] | 100% Completed | 18.65 s
# GCC cpu time 47.91s
# [########################################] | 100% Completed | 20.76 s
# GCC cpu time 24.55s
# [########################################] | 100% Completed | 21.73 s
# GCC cpu time 24.50s
# [########################################] | 100% Completed | 21.62 s
# GCC cpu time 22.28s
# [########################################] | 100% Completed | 22.13 s
# GCC cpu time 22.58s
# [########################################] | 100% Completed | 22.80 s
# GCC cpu time 23.48s
# Features derived from time signal in 455.40 s
# i_mc = 44
# [########################################] | 100% Completed | 18.18 s
# GCC cpu time 49.75s
# [########################################] | 100% Completed | 21.32 s
# GCC cpu time 24.20s
# [########################################] | 100% Completed | 21.91 s
# GCC cpu time 23.79s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 22.85s
# [########################################] | 100% Completed | 22.19 s
# GCC cpu time 25.34s
# [########################################] | 100% Completed | 21.68 s
# GCC cpu time 22.91s
# Features derived from time signal in 458.97 s
# i_mc = 45
# [########################################] | 100% Completed | 18.90 s
# GCC cpu time 43.91s
# [########################################] | 100% Completed | 21.59 s
# GCC cpu time 22.97s
# [########################################] | 100% Completed | 22.55 s
# GCC cpu time 24.46s
# [########################################] | 100% Completed | 22.44 s
# GCC cpu time 23.31s
# [########################################] | 100% Completed | 22.33 s
# GCC cpu time 23.34s
# [########################################] | 100% Completed | 22.75 s
# GCC cpu time 23.45s
# Features derived from time signal in 452.36 s
# i_mc = 46
# [########################################] | 100% Completed | 20.32 s
# GCC cpu time 46.59s
# [########################################] | 100% Completed | 20.91 s
# GCC cpu time 22.67s
# [########################################] | 100% Completed | 21.80 s
# GCC cpu time 24.65s
# [########################################] | 100% Completed | 22.11 s
# GCC cpu time 24.22s
# [########################################] | 100% Completed | 22.35 s
# GCC cpu time 28.75s
# [########################################] | 100% Completed | 21.46 s
# GCC cpu time 26.38s
# Features derived from time signal in 475.50 s
# i_mc = 47
# [########################################] | 100% Completed | 19.57 s
# GCC cpu time 46.82s
# [########################################] | 100% Completed | 20.59 s
# GCC cpu time 23.89s
# [########################################] | 100% Completed | 21.92 s
# GCC cpu time 24.79s
# [########################################] | 100% Completed | 21.13 s
# GCC cpu time 22.54s
# [########################################] | 100% Completed | 22.27 s
# GCC cpu time 23.70s
# [########################################] | 100% Completed | 21.69 s
# GCC cpu time 24.50s
# Features derived from time signal in 462.39 s
# i_mc = 48
# [########################################] | 100% Completed | 19.64 s
# GCC cpu time 49.09s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 22.77s
# [########################################] | 100% Completed | 22.22 s
# GCC cpu time 25.22s
# [########################################] | 100% Completed | 21.17 s
# GCC cpu time 23.19s
# [########################################] | 100% Completed | 21.84 s
# GCC cpu time 23.34s
# [########################################] | 100% Completed | 21.40 s
# GCC cpu time 29.53s
# Features derived from time signal in 475.67 s
# i_mc = 49
# [########################################] | 100% Completed | 19.59 s
# GCC cpu time 48.28s
# [########################################] | 100% Completed | 20.12 s
# GCC cpu time 22.68s
# [########################################] | 100% Completed | 21.60 s
# GCC cpu time 23.62s
# [########################################] | 100% Completed | 21.15 s
# GCC cpu time 23.23s
# [########################################] | 100% Completed | 22.00 s
# GCC cpu time 22.78s
# [########################################] | 100% Completed | 22.57 s
# GCC cpu time 25.58s
# Features derived from time signal in 463.88 s
# i_mc = 50
# [########################################] | 100% Completed | 19.33 s
# GCC cpu time 48.01s
# [########################################] | 100% Completed | 19.85 s
# GCC cpu time 22.80s
# [########################################] | 100% Completed | 22.62 s
# GCC cpu time 25.44s
# [########################################] | 100% Completed | 20.72 s
# GCC cpu time 24.42s
# [########################################] | 100% Completed | 22.48 s
# GCC cpu time 23.19s
# [########################################] | 100% Completed | 22.72 s
# GCC cpu time 25.33s
# Features derived from time signal in 489.16 s
# i_mc = 51
# [########################################] | 100% Completed | 18.34 s
# GCC cpu time 50.13s
# [########################################] | 100% Completed | 20.73 s
# GCC cpu time 23.81s
# [########################################] | 100% Completed | 22.51 s
# GCC cpu time 23.87s
# [########################################] | 100% Completed | 22.01 s
# GCC cpu time 25.29s
# [########################################] | 100% Completed | 22.79 s
# GCC cpu time 27.16s
# [########################################] | 100% Completed | 21.84 s
# GCC cpu time 24.50s
# Features derived from time signal in 453.49 s
# i_mc = 52
# [########################################] | 100% Completed | 19.89 s
# GCC cpu time 50.22s
# [########################################] | 100% Completed | 20.41 s
# GCC cpu time 22.13s
# [########################################] | 100% Completed | 22.02 s
# GCC cpu time 22.89s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 27.62s
# [########################################] | 100% Completed | 21.15 s
# GCC cpu time 23.22s
# [########################################] | 100% Completed | 21.71 s
# GCC cpu time 24.67s
# Features derived from time signal in 469.85 s
# i_mc = 53
# [########################################] | 100% Completed | 19.10 s
# GCC cpu time 45.25s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 24.96s
# [########################################] | 100% Completed | 21.90 s
# GCC cpu time 24.39s
# [########################################] | 100% Completed | 21.65 s
# GCC cpu time 26.53s
# [########################################] | 100% Completed | 21.53 s
# GCC cpu time 22.60s
# [########################################] | 100% Completed | 22.11 s
# GCC cpu time 24.48s
# Features derived from time signal in 479.74 s
# i_mc = 54
# [########################################] | 100% Completed | 18.07 s
# GCC cpu time 55.43s
# [########################################] | 100% Completed | 20.64 s
# GCC cpu time 23.71s
# [########################################] | 100% Completed | 21.87 s
# GCC cpu time 23.95s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 23.04s
# [########################################] | 100% Completed | 22.29 s
# GCC cpu time 22.44s
# [########################################] | 100% Completed | 21.95 s
# GCC cpu time 24.17s
# Features derived from time signal in 478.74 s
# i_mc = 55
# [########################################] | 100% Completed | 19.74 s
# GCC cpu time 50.56s
# [########################################] | 100% Completed | 19.20 s
# GCC cpu time 22.55s
# [########################################] | 100% Completed | 21.35 s
# GCC cpu time 23.09s
# [########################################] | 100% Completed | 21.30 s
# GCC cpu time 26.28s
# [########################################] | 100% Completed | 21.63 s
# GCC cpu time 23.33s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 26.11s
# Features derived from time signal in 481.62 s
# i_mc = 56
# [########################################] | 100% Completed | 19.71 s
# GCC cpu time 50.75s
# [########################################] | 100% Completed | 20.55 s
# GCC cpu time 27.25s
# [########################################] | 100% Completed | 21.08 s
# GCC cpu time 26.20s
# [########################################] | 100% Completed | 21.61 s
# GCC cpu time 24.98s
# [########################################] | 100% Completed | 21.98 s
# GCC cpu time 25.28s
# [########################################] | 100% Completed | 21.98 s
# GCC cpu time 25.10s
# Features derived from time signal in 481.83 s
# i_mc = 57
# [########################################] | 100% Completed | 19.76 s
# GCC cpu time 39.84s
# [########################################] | 100% Completed | 20.69 s
# GCC cpu time 23.73s
# [########################################] | 100% Completed | 21.06 s
# GCC cpu time 24.51s
# [########################################] | 100% Completed | 20.46 s
# GCC cpu time 23.37s
# [########################################] | 100% Completed | 21.46 s
# GCC cpu time 24.50s
# [########################################] | 100% Completed | 22.50 s
# GCC cpu time 22.64s
# Features derived from time signal in 451.75 s
# i_mc = 58
# [########################################] | 100% Completed | 19.79 s
# GCC cpu time 50.45s
# [########################################] | 100% Completed | 20.66 s
# GCC cpu time 24.11s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 25.81s
# [########################################] | 100% Completed | 22.04 s
# GCC cpu time 26.43s
# [########################################] | 100% Completed | 22.31 s
# GCC cpu time 25.08s
# [########################################] | 100% Completed | 22.59 s
# GCC cpu time 24.79s
# Features derived from time signal in 481.55 s
# i_mc = 59
# [########################################] | 100% Completed | 19.74 s
# GCC cpu time 54.25s
# [########################################] | 100% Completed | 20.85 s
# GCC cpu time 22.76s
# [########################################] | 100% Completed | 20.85 s
# GCC cpu time 24.97s
# [########################################] | 100% Completed | 21.65 s
# GCC cpu time 22.95s
# [########################################] | 100% Completed | 21.86 s
# GCC cpu time 23.88s
# [########################################] | 100% Completed | 21.88 s
# GCC cpu time 23.36s
# Features derived from time signal in 483.42 s
# i_mc = 60
# [########################################] | 100% Completed | 19.92 s
# GCC cpu time 54.92s
# [########################################] | 100% Completed | 20.77 s
# GCC cpu time 25.90s
# [########################################] | 100% Completed | 20.18 s
# GCC cpu time 24.17s
# [########################################] | 100% Completed | 21.85 s
# GCC cpu time 24.68s
# [########################################] | 100% Completed | 21.91 s
# GCC cpu time 26.49s
# [########################################] | 100% Completed | 20.31 s
# GCC cpu time 23.31s
# Features derived from time signal in 496.97 s
# i_mc = 61
# [########################################] | 100% Completed | 20.00 s
# GCC cpu time 52.07s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 23.86s
# [########################################] | 100% Completed | 21.18 s
# GCC cpu time 22.39s
# [########################################] | 100% Completed | 21.75 s
# GCC cpu time 22.70s
# [########################################] | 100% Completed | 22.58 s
# GCC cpu time 24.84s
# [########################################] | 100% Completed | 22.11 s
# GCC cpu time 23.35s
# Features derived from time signal in 457.34 s
# i_mc = 62
# [########################################] | 100% Completed | 18.89 s
# GCC cpu time 47.10s
# [########################################] | 100% Completed | 20.09 s
# GCC cpu time 23.47s
# [########################################] | 100% Completed | 21.66 s
# GCC cpu time 23.22s
# [########################################] | 100% Completed | 22.18 s
# GCC cpu time 24.72s
# [########################################] | 100% Completed | 22.20 s
# GCC cpu time 23.64s
# [########################################] | 100% Completed | 21.47 s
# GCC cpu time 30.56s
# Features derived from time signal in 468.76 s
# i_mc = 63
# [########################################] | 100% Completed | 19.83 s
# GCC cpu time 50.83s
# [########################################] | 100% Completed | 20.66 s
# GCC cpu time 22.73s
# [########################################] | 100% Completed | 21.12 s
# GCC cpu time 22.23s
# [########################################] | 100% Completed | 20.82 s
# GCC cpu time 25.92s
# [########################################] | 100% Completed | 20.96 s
# GCC cpu time 23.09s
# [########################################] | 100% Completed | 21.37 s
# GCC cpu time 22.35s
# Features derived from time signal in 454.24 s
# i_mc = 64
# [########################################] | 100% Completed | 20.04 s
# GCC cpu time 44.35s
# [########################################] | 100% Completed | 21.17 s
# GCC cpu time 23.80s
# [########################################] | 100% Completed | 22.19 s
# GCC cpu time 24.30s
# [########################################] | 100% Completed | 22.42 s
# GCC cpu time 27.12s
# [########################################] | 100% Completed | 21.60 s
# GCC cpu time 23.29s
# [########################################] | 100% Completed | 22.27 s
# GCC cpu time 23.24s
# Features derived from time signal in 456.02 s
# i_mc = 65
# [########################################] | 100% Completed | 18.19 s
# GCC cpu time 54.09s
# [########################################] | 100% Completed | 20.72 s
# GCC cpu time 23.83s
# [########################################] | 100% Completed | 21.21 s
# GCC cpu time 22.87s
# [########################################] | 100% Completed | 21.84 s
# GCC cpu time 23.83s
# [########################################] | 100% Completed | 21.61 s
# GCC cpu time 22.68s
# [########################################] | 100% Completed | 22.02 s
# GCC cpu time 25.09s
# Features derived from time signal in 473.60 s
# i_mc = 66
# [########################################] | 100% Completed | 19.64 s
# GCC cpu time 62.10s
# [########################################] | 100% Completed | 20.70 s
# GCC cpu time 24.18s
# [########################################] | 100% Completed | 21.19 s
# GCC cpu time 22.98s
# [########################################] | 100% Completed | 22.03 s
# GCC cpu time 26.33s
# [########################################] | 100% Completed | 22.29 s
# GCC cpu time 27.57s
# [########################################] | 100% Completed | 21.74 s
# GCC cpu time 23.83s
# Features derived from time signal in 497.77 s
# i_mc = 67
# [########################################] | 100% Completed | 19.82 s
# GCC cpu time 56.05s
# [########################################] | 100% Completed | 20.94 s
# GCC cpu time 24.04s
# [########################################] | 100% Completed | 21.23 s
# GCC cpu time 23.80s
# [########################################] | 100% Completed | 21.19 s
# GCC cpu time 24.45s
# [########################################] | 100% Completed | 22.04 s
# GCC cpu time 25.63s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 22.87s
# Features derived from time signal in 485.59 s
# i_mc = 68
# [########################################] | 100% Completed | 20.10 s
# GCC cpu time 53.27s
# [########################################] | 100% Completed | 20.83 s
# GCC cpu time 24.61s
# [########################################] | 100% Completed | 21.03 s
# GCC cpu time 26.06s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 23.15s
# [########################################] | 100% Completed | 21.94 s
# GCC cpu time 25.24s
# [########################################] | 100% Completed | 21.88 s
# GCC cpu time 25.32s
# Features derived from time signal in 467.53 s
# i_mc = 69
# [########################################] | 100% Completed | 19.82 s
# GCC cpu time 44.58s
# [########################################] | 100% Completed | 20.68 s
# GCC cpu time 26.94s
# [########################################] | 100% Completed | 21.89 s
# GCC cpu time 25.34s
# [########################################] | 100% Completed | 21.85 s
# GCC cpu time 28.19s
# [########################################] | 100% Completed | 21.45 s
# GCC cpu time 25.26s
# [########################################] | 100% Completed | 21.02 s
# GCC cpu time 22.92s
# Features derived from time signal in 491.01 s
# i_mc = 70
# [########################################] | 100% Completed | 18.75 s
# GCC cpu time 53.25s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 22.78s
# [########################################] | 100% Completed | 22.10 s
# GCC cpu time 24.17s
# [########################################] | 100% Completed | 21.84 s
# GCC cpu time 23.35s
# [########################################] | 100% Completed | 22.02 s
# GCC cpu time 25.25s
# [########################################] | 100% Completed | 20.94 s
# GCC cpu time 23.22s
# Features derived from time signal in 474.92 s
# i_mc = 71
# [########################################] | 100% Completed | 18.65 s
# GCC cpu time 66.65s
# [########################################] | 100% Completed | 20.85 s
# GCC cpu time 22.81s
# [########################################] | 100% Completed | 20.87 s
# GCC cpu time 23.46s
# [########################################] | 100% Completed | 21.87 s
# GCC cpu time 25.56s
# [########################################] | 100% Completed | 21.29 s
# GCC cpu time 29.39s
# [########################################] | 100% Completed | 21.42 s
# GCC cpu time 24.60s
# Features derived from time signal in 492.72 s
# i_mc = 72
# [########################################] | 100% Completed | 19.67 s
# GCC cpu time 51.69s
# [########################################] | 100% Completed | 20.88 s
# GCC cpu time 24.61s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 22.36s
# [########################################] | 100% Completed | 21.54 s
# GCC cpu time 24.76s
# [########################################] | 100% Completed | 21.46 s
# GCC cpu time 24.85s
# [########################################] | 100% Completed | 22.31 s
# GCC cpu time 26.45s
# Features derived from time signal in 476.19 s
# i_mc = 73
# [########################################] | 100% Completed | 19.15 s
# GCC cpu time 55.26s
# [########################################] | 100% Completed | 20.62 s
# GCC cpu time 24.41s
# [########################################] | 100% Completed | 20.51 s
# GCC cpu time 22.71s
# [########################################] | 100% Completed | 21.50 s
# GCC cpu time 23.26s
# [########################################] | 100% Completed | 21.54 s
# GCC cpu time 27.13s
# [########################################] | 100% Completed | 21.95 s
# GCC cpu time 29.89s
# Features derived from time signal in 503.61 s
# i_mc = 74
# [########################################] | 100% Completed | 20.30 s
# GCC cpu time 60.38s
# [########################################] | 100% Completed | 20.83 s
# GCC cpu time 22.25s
# [########################################] | 100% Completed | 21.27 s
# GCC cpu time 24.05s
# [########################################] | 100% Completed | 20.89 s
# GCC cpu time 23.05s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 23.62s
# [########################################] | 100% Completed | 21.55 s
# GCC cpu time 24.30s
# Features derived from time signal in 508.81 s
# i_mc = 75
# [########################################] | 100% Completed | 18.65 s
# GCC cpu time 53.81s
# [########################################] | 100% Completed | 20.42 s
# GCC cpu time 25.58s
# [########################################] | 100% Completed | 20.88 s
# GCC cpu time 25.27s
# [########################################] | 100% Completed | 21.00 s
# GCC cpu time 29.48s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 30.84s
# [########################################] | 100% Completed | 20.88 s
# GCC cpu time 26.48s
# Features derived from time signal in 508.13 s
# i_mc = 76
# [########################################] | 100% Completed | 19.06 s
# GCC cpu time 52.19s
# [########################################] | 100% Completed | 20.88 s
# GCC cpu time 22.97s
# [########################################] | 100% Completed | 21.73 s
# GCC cpu time 22.73s
# [########################################] | 100% Completed | 21.56 s
# GCC cpu time 25.25s
# [########################################] | 100% Completed | 21.69 s
# GCC cpu time 24.66s
# [########################################] | 100% Completed | 21.99 s
# GCC cpu time 25.53s
# Features derived from time signal in 472.39 s
# i_mc = 77
# [########################################] | 100% Completed | 17.98 s
# GCC cpu time 47.34s
# [########################################] | 100% Completed | 21.19 s
# GCC cpu time 25.26s
# [########################################] | 100% Completed | 21.05 s
# GCC cpu time 25.01s
# [########################################] | 100% Completed | 21.29 s
# GCC cpu time 25.18s
# [########################################] | 100% Completed | 21.10 s
# GCC cpu time 30.13s
# [########################################] | 100% Completed | 21.99 s
# GCC cpu time 25.58s
# Features derived from time signal in 485.80 s
# i_mc = 78
# [########################################] | 100% Completed | 19.85 s
# GCC cpu time 50.87s
# [########################################] | 100% Completed | 20.53 s
# GCC cpu time 23.35s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 23.52s
# [########################################] | 100% Completed | 21.20 s
# GCC cpu time 23.91s
# [########################################] | 100% Completed | 21.68 s
# GCC cpu time 25.74s
# [########################################] | 100% Completed | 21.43 s
# GCC cpu time 23.21s
# Features derived from time signal in 465.26 s
# i_mc = 79
# [########################################] | 100% Completed | 19.86 s
# GCC cpu time 58.68s
# [########################################] | 100% Completed | 20.74 s
# GCC cpu time 24.75s
# [########################################] | 100% Completed | 21.26 s
# GCC cpu time 28.65s
# [########################################] | 100% Completed | 21.11 s
# GCC cpu time 26.08s
# [########################################] | 100% Completed | 21.16 s
# GCC cpu time 26.04s
# [########################################] | 100% Completed | 21.10 s
# GCC cpu time 25.01s
# Features derived from time signal in 523.31 s
# i_mc = 80
# [########################################] | 100% Completed | 19.67 s
# GCC cpu time 55.65s
# [########################################] | 100% Completed | 20.95 s
# GCC cpu time 23.69s
# [########################################] | 100% Completed | 21.18 s
# GCC cpu time 23.59s
# [########################################] | 100% Completed | 20.87 s
# GCC cpu time 25.24s
# [########################################] | 100% Completed | 21.46 s
# GCC cpu time 24.59s
# [########################################] | 100% Completed | 20.58 s
# GCC cpu time 29.65s
# Features derived from time signal in 493.77 s
# i_mc = 81
# [########################################] | 100% Completed | 20.68 s
# GCC cpu time 59.92s
# [########################################] | 100% Completed | 21.26 s
# GCC cpu time 27.53s
# [########################################] | 100% Completed | 20.57 s
# GCC cpu time 30.37s
# [########################################] | 100% Completed | 20.94 s
# GCC cpu time 24.16s
# [########################################] | 100% Completed | 21.22 s
# GCC cpu time 25.27s
# [########################################] | 100% Completed | 22.35 s
# GCC cpu time 22.39s
# Features derived from time signal in 516.44 s
# i_mc = 82
# [########################################] | 100% Completed | 18.84 s
# GCC cpu time 56.17s
# [########################################] | 100% Completed | 20.71 s
# GCC cpu time 30.54s
# [########################################] | 100% Completed | 20.63 s
# GCC cpu time 29.06s
# [########################################] | 100% Completed | 20.71 s
# GCC cpu time 23.65s
# [########################################] | 100% Completed | 21.56 s
# GCC cpu time 23.69s
# [########################################] | 100% Completed | 21.90 s
# GCC cpu time 25.12s
# Features derived from time signal in 497.25 s
# i_mc = 83
# [########################################] | 100% Completed | 19.29 s
# GCC cpu time 58.10s
# [########################################] | 100% Completed | 20.77 s
# GCC cpu time 22.73s
# [########################################] | 100% Completed | 21.14 s
# GCC cpu time 24.70s
# [########################################] | 100% Completed | 21.81 s
# GCC cpu time 26.50s
# [########################################] | 100% Completed | 21.76 s
# GCC cpu time 24.72s
# [########################################] | 100% Completed | 21.45 s
# GCC cpu time 25.64s
# Features derived from time signal in 478.58 s
# i_mc = 84
# [########################################] | 100% Completed | 19.97 s
# GCC cpu time 67.76s
# [########################################] | 100% Completed | 21.75 s
# GCC cpu time 24.66s
# [########################################] | 100% Completed | 20.66 s
# GCC cpu time 23.40s
# [########################################] | 100% Completed | 21.89 s
# GCC cpu time 24.21s
# [########################################] | 100% Completed | 21.64 s
# GCC cpu time 25.59s
# [########################################] | 100% Completed | 21.33 s
# GCC cpu time 29.79s
# Features derived from time signal in 510.25 s
# i_mc = 85
# [########################################] | 100% Completed | 20.01 s
# GCC cpu time 51.31s
# [########################################] | 100% Completed | 20.70 s
# GCC cpu time 23.32s
# [########################################] | 100% Completed | 20.96 s
# GCC cpu time 24.89s
# [########################################] | 100% Completed | 20.69 s
# GCC cpu time 27.19s
# [########################################] | 100% Completed | 21.53 s
# GCC cpu time 26.80s
# [########################################] | 100% Completed | 20.71 s
# GCC cpu time 24.85s
# Features derived from time signal in 505.26 s
# i_mc = 86
# [########################################] | 100% Completed | 20.39 s
# GCC cpu time 52.21s
# [########################################] | 100% Completed | 21.10 s
# GCC cpu time 25.29s
# [########################################] | 100% Completed | 21.38 s
# GCC cpu time 26.96s
# [########################################] | 100% Completed | 22.00 s
# GCC cpu time 24.80s
# [########################################] | 100% Completed | 20.61 s
# GCC cpu time 23.65s
# [########################################] | 100% Completed | 21.21 s
# GCC cpu time 25.72s
# Features derived from time signal in 503.46 s
# i_mc = 87
# [########################################] | 100% Completed | 18.96 s
# GCC cpu time 57.24s
# [########################################] | 100% Completed | 20.55 s
# GCC cpu time 24.18s
# [########################################] | 100% Completed | 21.07 s
# GCC cpu time 22.60s
# [########################################] | 100% Completed | 21.69 s
# GCC cpu time 22.89s
# [########################################] | 100% Completed | 21.73 s
# GCC cpu time 24.56s
# [########################################] | 100% Completed | 20.97 s
# GCC cpu time 25.11s
# Features derived from time signal in 471.85 s
# i_mc = 88
# [########################################] | 100% Completed | 19.48 s
# GCC cpu time 49.30s
# [########################################] | 100% Completed | 21.03 s
# GCC cpu time 22.89s
# [########################################] | 100% Completed | 23.16 s
# GCC cpu time 25.64s
# [########################################] | 100% Completed | 21.06 s
# GCC cpu time 24.53s
# [########################################] | 100% Completed | 21.76 s
# GCC cpu time 22.64s
# [########################################] | 100% Completed | 22.07 s
# GCC cpu time 24.64s
# Features derived from time signal in 475.46 s
# i_mc = 89
# [########################################] | 100% Completed | 19.53 s
# GCC cpu time 65.66s
# [########################################] | 100% Completed | 19.58 s
# GCC cpu time 34.59s
# [########################################] | 100% Completed | 20.92 s
# GCC cpu time 27.92s
# [########################################] | 100% Completed | 22.64 s
# GCC cpu time 22.40s
# [########################################] | 100% Completed | 22.63 s
# GCC cpu time 23.54s
# [########################################] | 100% Completed | 22.22 s
# GCC cpu time 40.87s
# Features derived from time signal in 519.75 s
# i_mc = 90
# [########################################] | 100% Completed | 19.15 s
# GCC cpu time 56.83s
# [########################################] | 100% Completed | 20.77 s
# GCC cpu time 22.72s
# [########################################] | 100% Completed | 21.71 s
# GCC cpu time 23.31s
# [########################################] | 100% Completed | 21.91 s
# GCC cpu time 23.06s
# [########################################] | 100% Completed | 21.97 s
# GCC cpu time 25.85s
# [########################################] | 100% Completed | 20.97 s
# GCC cpu time 24.73s
# Features derived from time signal in 473.04 s
# i_mc = 91
# [########################################] | 100% Completed | 19.63 s
# GCC cpu time 56.35s
# [########################################] | 100% Completed | 20.50 s
# GCC cpu time 24.26s
# [########################################] | 100% Completed | 21.62 s
# GCC cpu time 24.93s
# [########################################] | 100% Completed | 21.44 s
# GCC cpu time 25.94s
# [########################################] | 100% Completed | 22.21 s
# GCC cpu time 24.16s
# [########################################] | 100% Completed | 21.78 s
# GCC cpu time 26.23s
# Features derived from time signal in 478.21 s
# i_mc = 92
# [########################################] | 100% Completed | 18.69 s
# GCC cpu time 52.16s
# [########################################] | 100% Completed | 20.86 s
# GCC cpu time 22.59s
# [########################################] | 100% Completed | 21.17 s
# GCC cpu time 24.60s
# [########################################] | 100% Completed | 21.33 s
# GCC cpu time 25.26s
# [########################################] | 100% Completed | 22.17 s
# GCC cpu time 26.74s
# [########################################] | 100% Completed | 22.14 s
# GCC cpu time 23.06s
# Features derived from time signal in 507.55 s
# i_mc = 93
# [########################################] | 100% Completed | 20.33 s
# GCC cpu time 61.38s
# [########################################] | 100% Completed | 21.23 s
# GCC cpu time 24.47s
# [########################################] | 100% Completed | 21.07 s
# GCC cpu time 22.13s
# [########################################] | 100% Completed | 21.38 s
# GCC cpu time 21.98s
# [########################################] | 100% Completed | 20.69 s
# GCC cpu time 22.00s
# [########################################] | 100% Completed | 21.56 s
# GCC cpu time 22.57s
# Features derived from time signal in 502.27 s
# i_mc = 94
# [########################################] | 100% Completed | 20.10 s
# GCC cpu time 66.00s
# [########################################] | 100% Completed | 20.49 s
# GCC cpu time 24.83s
# [########################################] | 100% Completed | 21.79 s
# GCC cpu time 24.51s
# [########################################] | 100% Completed | 22.34 s
# GCC cpu time 26.68s
# [########################################] | 100% Completed | 21.93 s
# GCC cpu time 29.15s
# [########################################] | 100% Completed | 21.56 s
# GCC cpu time 25.42s
# Features derived from time signal in 510.72 s
# i_mc = 95
# [########################################] | 100% Completed | 19.66 s
# GCC cpu time 56.78s
# [########################################] | 100% Completed | 21.25 s
# GCC cpu time 23.01s
# [########################################] | 100% Completed | 21.35 s
# GCC cpu time 25.26s
# [########################################] | 100% Completed | 21.51 s
# GCC cpu time 24.71s
# [########################################] | 100% Completed | 22.13 s
# GCC cpu time 23.36s
# [########################################] | 100% Completed | 22.01 s
# GCC cpu time 26.21s
# Features derived from time signal in 520.73 s
# i_mc = 96
# [########################################] | 100% Completed | 19.34 s
# GCC cpu time 60.87s
# [########################################] | 100% Completed | 20.97 s
# GCC cpu time 25.43s
# [########################################] | 100% Completed | 20.85 s
# GCC cpu time 22.81s
# [########################################] | 100% Completed | 22.69 s
# GCC cpu time 23.52s
# [########################################] | 100% Completed | 21.59 s
# GCC cpu time 24.00s
# [########################################] | 100% Completed | 21.71 s
# GCC cpu time 24.70s
# Features derived from time signal in 486.05 s
# i_mc = 97
# [########################################] | 100% Completed | 19.77 s
# GCC cpu time 48.52s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 22.95s
# [########################################] | 100% Completed | 23.28 s
# GCC cpu time 23.41s
# [########################################] | 100% Completed | 22.74 s
# GCC cpu time 23.56s
# [########################################] | 100% Completed | 22.04 s
# GCC cpu time 22.70s
# [########################################] | 100% Completed | 21.80 s
# GCC cpu time 21.99s
# Features derived from time signal in 474.65 s
# i_mc = 98
# [########################################] | 100% Completed | 19.75 s
# GCC cpu time 45.46s
# [########################################] | 100% Completed | 21.28 s
# GCC cpu time 24.86s
# [########################################] | 100% Completed | 21.62 s
# GCC cpu time 22.96s
# [########################################] | 100% Completed | 21.88 s
# GCC cpu time 23.71s
# [########################################] | 100% Completed | 22.23 s
# GCC cpu time 23.64s
# [########################################] | 100% Completed | 22.98 s
# GCC cpu time 27.71s
# Features derived from time signal in 534.32 s
# i_mc = 99
# [########################################] | 100% Completed | 20.60 s
# GCC cpu time 53.33s
# [########################################] | 100% Completed | 21.36 s
# GCC cpu time 25.25s
# [########################################] | 100% Completed | 21.54 s
# GCC cpu time 25.70s
# [########################################] | 100% Completed | 22.44 s
# GCC cpu time 26.37s
# [########################################] | 100% Completed | 22.73 s
# GCC cpu time 25.38s
# [########################################] | 100% Completed | 22.19 s
# GCC cpu time 25.05s
# Features derived from time signal in 487.01 s
# i_mc = 100
# [########################################] | 100% Completed | 19.91 s
# GCC cpu time 84.77s
# [########################################] | 100% Completed | 20.35 s
# GCC cpu time 31.32s
# [########################################] | 100% Completed | 21.10 s
# GCC cpu time 29.60s
# [########################################] | 100% Completed | 21.11 s
# GCC cpu time 22.78s
# [########################################] | 100% Completed | 22.80 s
# GCC cpu time 42.28s
# [########################################] | 100% Completed | 21.31 s
# GCC cpu time 23.35s
# Features derived from time signal in 558.99 s
# i_mc = 101
# [########################################] | 100% Completed | 19.97 s
# GCC cpu time 56.70s
# [########################################] | 100% Completed | 20.73 s
# GCC cpu time 23.61s
# [########################################] | 100% Completed | 21.79 s
# GCC cpu time 24.58s
# [########################################] | 100% Completed | 21.34 s
# GCC cpu time 22.75s
# [########################################] | 100% Completed | 23.31 s
# GCC cpu time 26.49s
# [########################################] | 100% Completed | 22.27 s
# GCC cpu time 24.44s
# Features derived from time signal in 505.63 s
# i_mc = 102
# [########################################] | 100% Completed | 19.31 s
# GCC cpu time 53.13s
# [########################################] | 100% Completed | 21.24 s
# GCC cpu time 23.36s
# [########################################] | 100% Completed | 22.14 s
# GCC cpu time 23.65s
# [########################################] | 100% Completed | 23.18 s
# GCC cpu time 27.32s
# [########################################] | 100% Completed | 25.39 s
# GCC cpu time 31.05s
# [########################################] | 100% Completed | 22.53 s
# GCC cpu time 23.02s
# Features derived from time signal in 536.75 s
# i_mc = 103
# [########################################] | 100% Completed | 21.16 s
# GCC cpu time 64.00s
# [########################################] | 100% Completed | 21.76 s
# GCC cpu time 28.53s
# [########################################] | 100% Completed | 22.59 s
# GCC cpu time 26.22s
# [########################################] | 100% Completed | 23.33 s
# GCC cpu time 26.41s
# [########################################] | 100% Completed | 23.92 s
# GCC cpu time 26.61s
# [########################################] | 100% Completed | 24.45 s
# GCC cpu time 25.36s
# Features derived from time signal in 533.39 s
# i_mc = 104
# [########################################] | 100% Completed | 22.43 s
# GCC cpu time 67.67s
# [########################################] | 100% Completed | 23.55 s
# GCC cpu time 25.05s
# [########################################] | 100% Completed | 23.54 s
# GCC cpu time 29.85s
# [########################################] | 100% Completed | 23.55 s
# GCC cpu time 27.26s
# [########################################] | 100% Completed | 23.90 s
# GCC cpu time 27.95s
# [########################################] | 100% Completed | 24.32 s
# GCC cpu time 26.48s
# Features derived from time signal in 570.03 s
# i_mc = 105
# [########################################] | 100% Completed | 22.86 s
# GCC cpu time 63.17s
# [########################################] | 100% Completed | 23.04 s
# GCC cpu time 27.18s
# [########################################] | 100% Completed | 27.55 s
# GCC cpu time 27.72s
# [########################################] | 100% Completed | 20.98 s
# GCC cpu time 23.47s
# [########################################] | 100% Completed | 22.80 s
# GCC cpu time 25.77s
# [########################################] | 100% Completed | 22.32 s
# GCC cpu time 30.87s
# Features derived from time signal in 550.82 s
# i_mc = 106
# [########################################] | 100% Completed | 20.58 s
# GCC cpu time 62.96s
# [########################################] | 100% Completed | 21.73 s
# GCC cpu time 22.96s
# [########################################] | 100% Completed | 21.98 s
# GCC cpu time 22.43s
# [########################################] | 100% Completed | 23.55 s
# GCC cpu time 25.24s
# [########################################] | 100% Completed | 23.45 s
# GCC cpu time 26.38s
# [########################################] | 100% Completed | 23.50 s
# GCC cpu time 32.81s
# Features derived from time signal in 515.36 s
# i_mc = 107
# [########################################] | 100% Completed | 20.58 s
# GCC cpu time 52.17s
# [########################################] | 100% Completed | 22.74 s
# GCC cpu time 25.16s
# [########################################] | 100% Completed | 21.82 s
# GCC cpu time 25.40s
# [########################################] | 100% Completed | 22.60 s
# GCC cpu time 23.78s
# [########################################] | 100% Completed | 23.38 s
# GCC cpu time 27.25s
# [########################################] | 100% Completed | 21.57 s
# GCC cpu time 23.52s
# Features derived from time signal in 531.49 s
# i_mc = 108
# [########################################] | 100% Completed | 19.90 s
# GCC cpu time 72.59s
# [########################################] | 100% Completed | 22.10 s
# GCC cpu time 23.01s
# [########################################] | 100% Completed | 22.81 s
# GCC cpu time 22.53s
# [########################################] | 100% Completed | 23.53 s
# GCC cpu time 22.94s
# [########################################] | 100% Completed | 22.78 s
# GCC cpu time 22.08s
# [########################################] | 100% Completed | 23.16 s
# GCC cpu time 22.16s
# Features derived from time signal in 511.37 s
# i_mc = 109
# [########################################] | 100% Completed | 20.45 s
# GCC cpu time 38.62s
# [########################################] | 100% Completed | 22.19 s
# GCC cpu time 219.98s
# [########################################] | 100% Completed | 21.23 s
# GCC cpu time 295.82s
# [########################################] | 100% Completed | 20.89 s
# GCC cpu time 390.13s
# [########################################] | 100% Completed | 20.81 s
# GCC cpu time 818.42s
# [########################################] | 100% Completed | 20.96 s
# GCC cpu time 355.72s
# Features derived from time signal in 3181.09 s

# %%
# Etude des métriques vs nombre de capteurs dans la sous-antenne
study_perf_vs_subarrays(subarrays_list, snrs, var="std")
study_perf_vs_subarrays(subarrays_list, snrs, var="minmax")
